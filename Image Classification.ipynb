# %% [markdown]
# # Submit your pdf report as well as your ipynb file to Avenue (separate files). Make sure your pdf report includes all the plots, results, and analyses.
#
#
# # SVM and Logistic Regression with PyTorch Implementation
# In this exercise, we explore a machine learning framework called PyTorch. We will use the framework to implement SVM and Logistic Regression models and address a multi-class image classification problem.
#
# # Submission
# - There are four tasks for you.
# - Report the results and answer the questions in a pdf file.
# - Additionally, submit your code in the same Jupiter notebook format. (keep the overal format of the notebook unchanged)

# %%
# Hyperparameters for training a neural network on the MNIST dataset

# Learning rate controls the step size of gradient descent, determining how much to update the weights in each iteration.
learning_rate = 0.02

# Number of epochs specifies how many complete passes through the training dataset will be performed.
num_epochs = 100

# Batch size defines the number of images processed in each mini-batch during training.
batch_size = 32

# Percentage of the dataset to be used for training, allowing for experimentation with smaller subsets of data.
train_data_percentage = 0.0025
test_data_percentage = 0.1

# Input size corresponds to the dimensions of the MNIST images, flattened from 28x28 pixels.
input_size = 28 * 28  # MNIST image size

# Number of output classes, representing the digits 0 through 9 in the MNIST dataset.
num_classes = 10  # Number of classes in MNIST

# %%
import torch
from torchvision import datasets, transforms
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, random_split

# %% [markdown]
# # Dataset characteristics
# We use the MNIST digit classification data set for this assignment.
# A total of 60K images for training and 10K images for testing are available. But we only use a small percentage of them. Images are 28 x 28 pixels.

# %%
# Load MNIST datasets, and create pytorch data loader to read data in mini-batches
def get_data_loaders(train_data_percentage, test_data_percentage, batch_size, transform):
    # Load the entire MNIST dataset
    # For train and test data points we sometimes use different transforms.
    # This becomes handy in the last task (data augmentation)
    full_train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    test_transform = transforms.Compose([transforms.ToTensor()])
    full_test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=test_transform)

    # Calculate the size based on the percentage
    train_size = int(train_data_percentage * len(full_train_dataset))  # percentage of training data
    test_size = int(test_data_percentage * len(full_test_dataset))    # percentage of test data
    train_remainder = len(full_train_dataset) - train_size
    test_remainder = len(full_test_dataset) - test_size

    # Split the dataset into the percentage specified and the remaining
    train_dataset, _ = random_split(full_train_dataset, [train_size, train_remainder])
    test_dataset, _ = random_split(full_test_dataset, [test_size, test_remainder])

    # Create DataLoaders for batching and shuffling
    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, test_loader

# %%
# Define transformation (convert to tensor)
transform = transforms.Compose([transforms.ToTensor()])
train_loader, test_loader = get_data_loaders(train_data_percentage, test_data_percentage,batch_size, transform)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 16.1MB/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 490kB/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.47MB/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 10.5MB/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
# Get first batch of images and labels
train_image_batch, classe_set = next(iter(train_loader))

print(f'train_loader contains {len(train_loader)} batches of data.')
print(f'train_image_batch has shape {train_image_batch.shape},')
print('where 64 is the number of images in a batch, 1 is the number of image channels (1 for grayscale image),\
 28X28 stands for WxH (width and height of a single image).')
# Out:
# train_loader contains 5 batches of data.
# train_image_batch has shape torch.Size([32, 1, 28, 28]),
# where 64 is the number of images in a batch, 1 is the number of image channels (1 for grayscale image), 28X28 stands for WxH (width and height of a single image).

# %% [markdown]
# # Visualization of the dataset

# %%
def show_gray_digits(image_set, row=2, col=3):
    # Here we visualize some of the data points in the data set.
    # Create a large figure, to be filled with multiple subplots.

    # Since image_set is a tensor variable, we transform it to a numpy type variable.
    image_set = image_set.cpu().detach().numpy()

    for i in range(row*col):
      # define subplot
      plt.subplot(row, col, i+1)
      # plot raw pixel data
      plt.imshow(image_set[i,0], cmap=plt.get_cmap('gray'))
    # show the figure
    plt.show()

# %%
# display images and their corresponding labels.
show_gray_digits(train_image_batch, 2, 3)
print(classe_set[:6])

del train_image_batch, classe_set, train_loader, test_loader, transform
# Out:
# tensor([8, 7, 2, 4, 0, 4])

# %% [markdown]
# # Task 1: Linear SVM for MNIST classification (30 points).
# In this part, you are provided with the implementation of a multi-class linear SVM model and the basic MNIST classfication workflow. Run the given code and try to understand how it works.

# %% [markdown]
# ## Part A (5 points):
#
# Is the implementation of the multi-class linear SVM similar to the end-to-end multiclass SVM that we learned in the class? Are there any significant differences?

# %% [markdown]
# ## Part B (15 points):
# 1. Compute the accuracy on the train and test set after each epoch in the training. Plot these accuracies as a function of the epoch number and include it in the report (include only the plot in your report, not all the 2*100 numbers).
#
# 2. Compute the hinge loss on the train and test set after each epoch in the training. Plot these loss values as a function of the epoch number and include it in the report.(include only the plot in your report, not all the 2*100 numbers)
#
# 3. Report the **last** epoch results (including loss values and accuracies) for both train and test sets.
#
# 4. Does the model shows significant overfitting? Or do you think there might be other factors that are more significant in the mediocre performance of the model?

# %%
# Function to plot train/test loss and accuracy on separate subplots
def plot_eval_results(train_loss, test_loss, train_acc, test_acc):
    """
    Plots the training and testing loss/accuracy over the number of epochs.

    Parameters:
    - train_loss: list or array, the training loss values over epochs.
    - test_loss: list or array, the testing loss values over epochs.
    - train_acc: list or array, the training accuracy values over epochs.
    - test_acc: list or array, the testing accuracy values over epochs.
    """


    # Create subplots (1 row, 2 columns) for loss and accuracy
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))  # figsize sets the overall plot size

    # Plot Loss on the first subplot
    ax1.plot(range(len(train_loss)), train_loss, label="Training Loss", color='blue')
    ax1.plot(range(len(test_loss)), test_loss, label="Testing Loss", color='red')

    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    ax1.set_title("Train vs Test Loss over epochs")


    # Plot Accuracy on the second subplot
    ax2.plot(range(len(train_acc)), train_acc, label="Training Accuracy", color="blue")
    ax2.plot(range(len(test_acc)), test_acc, label="Testing Accuracy", color="red")


    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Accuracy')
    ax2.set_title("Train vs Test Accuracy over epochs")

    # Adjust layout to avoid subplot overlap
    plt.tight_layout()
    ax1.legend(loc="lower right")
    ax2.legend(loc="lower right")




    # Display the plots
    plt.show()

# %%
# Define a linear SVM model
class LinearSVM(nn.Module):
    def __init__(self, input_size, num_classes):
        super(LinearSVM, self).__init__()
        self.fc = nn.Linear(input_size, num_classes, bias=True)

    def forward(self, x):
        # Flatten the image
        x= x.view(-1, input_size)
        return self.fc(x)

# %%
# Load MNIST dataset
transform = transforms.Compose([transforms.ToTensor()])
train_loader, test_loader = get_data_loaders(train_data_percentage, test_data_percentage, batch_size, transform)

# %%
# Return model loss and accuracy with the provided criterion and data_loader.
def eval(model, data_loader, criterion=None):
  model.eval()
  correct = 0
  total = 0
  loss_batches = []

  # Switch to evaluation mode and turn off gradient calculation
  # since parameters are not updated during testing.
  with torch.no_grad():
      for images_batch, labels_batch in data_loader:
          outputs = model(images_batch)
          # The predicted label is the output with the highest activation.
          _, predicted = torch.max(outputs.data, 1)
          total += labels_batch.size(0)
          correct += (predicted == labels_batch).sum().item()

          # Use provided criterion to calculate the loss for the mini batch
          # Append the mini-batch loss to loss_batches array
          batch_loss = criterion(outputs, labels_batch)
          loss_batches.append(batch_loss.item())

  accuracy = 100 * correct / total
  loss = np.mean(loss_batches)

  model.train()

  return accuracy, loss

# %%
# Initialize the model, loss function, and optimizer
model = LinearSVM(input_size, num_classes)
criterion = nn.MultiMarginLoss()  # A Multi-class version of Hinge loss
optimizer = optim.SGD(model.parameters(), lr=learning_rate)


train_loss_epochs = []
test_loss_epochs = []
train_accuracy_epochs = []
test_accuracy_epochs = []

# Training the model
for epoch in range(num_epochs):
    for i, (images_batch, labels_batch) in enumerate(train_loader):
        optimizer.zero_grad() # Clear the gradients
        outputs = model(images_batch) # Forward pass
        loss = criterion(outputs, labels_batch) # Calculate loss
        loss.backward() # Backward pass
        optimizer.step() # Update weights

    # Obtain train/test loss values and accuracies after each epoch
    train_accuracy, train_loss = eval(model, train_loader, criterion)
    test_accuracy, test_loss = eval(model, test_loader, criterion)

    print(f'Epoch {epoch+1:02d} - Train loss: {train_loss:.6f}, Train accuracy: {train_accuracy:.2f}%')
    print(f'         - Test loss: {test_loss:.6f}, Test accuracy: {test_accuracy:.2f}%')
    print("-------------------------------------------------------------")

    train_loss_epochs.append(train_loss)
    test_loss_epochs.append(test_loss)
    train_accuracy_epochs.append(train_accuracy)
    test_accuracy_epochs.append(test_accuracy)
# Out:
# Epoch 01 - Train loss: 0.748147, Train accuracy: 31.33%
#          - Test loss: 0.804460, Test accuracy: 23.00%
# -------------------------------------------------------------
# Epoch 02 - Train loss: 0.618156, Train accuracy: 42.00%
#          - Test loss: 0.705024, Test accuracy: 33.40%
# -------------------------------------------------------------
# Epoch 03 - Train loss: 0.518386, Train accuracy: 50.67%
#          - Test loss: 0.620016, Test accuracy: 40.50%
# -------------------------------------------------------------
# Epoch 04 - Train loss: 0.436713, Train accuracy: 58.00%
#          - Test loss: 0.549627, Test accuracy: 45.60%
# -------------------------------------------------------------
# Epoch 05 - Train loss: 0.363107, Train accuracy: 64.00%
#          - Test loss: 0.489876, Test accuracy: 51.30%
# -------------------------------------------------------------
# Epoch 06 - Train loss: 0.320999, Train accuracy: 66.67%
#          - Test loss: 0.441145, Test accuracy: 53.70%
# -------------------------------------------------------------
# Epoch 07 - Train loss: 0.279186, Train accuracy: 70.00%
#          - Test loss: 0.398410, Test accuracy: 58.50%
# -------------------------------------------------------------
# Epoch 08 - Train loss: 0.248011, Train accuracy: 75.33%
#          - Test loss: 0.363663, Test accuracy: 61.60%
# -------------------------------------------------------------
# Epoch 09 - Train loss: 0.216481, Train accuracy: 78.00%
#          - Test loss: 0.335602, Test accuracy: 64.80%
# -------------------------------------------------------------
# Epoch 10 - Train loss: 0.197673, Train accuracy: 81.33%
#          - Test loss: 0.315929, Test accuracy: 68.20%
# -------------------------------------------------------------
# Epoch 11 - Train loss: 0.181518, Train accuracy: 82.00%
#          - Test loss: 0.300068, Test accuracy: 68.00%
# -------------------------------------------------------------
# Epoch 12 - Train loss: 0.167569, Train accuracy: 85.33%
#          - Test loss: 0.286066, Test accuracy: 71.20%
# -------------------------------------------------------------
# Epoch 13 - Train loss: 0.158062, Train accuracy: 87.33%
#          - Test loss: 0.274658, Test accuracy: 72.40%
# -------------------------------------------------------------
# Epoch 14 - Train loss: 0.146435, Train accuracy: 88.67%
#          - Test loss: 0.265070, Test accuracy: 72.90%
# -------------------------------------------------------------
# Epoch 15 - Train loss: 0.137930, Train accuracy: 90.00%
#          - Test loss: 0.255831, Test accuracy: 73.90%
# -------------------------------------------------------------
# Epoch 16 - Train loss: 0.130669, Train accuracy: 90.00%
#          - Test loss: 0.249027, Test accuracy: 73.70%
# -------------------------------------------------------------
# Epoch 17 - Train loss: 0.121168, Train accuracy: 90.67%
#          - Test loss: 0.243356, Test accuracy: 74.00%
# -------------------------------------------------------------
# Epoch 18 - Train loss: 0.114822, Train accuracy: 92.00%
#          - Test loss: 0.238105, Test accuracy: 74.30%
# -------------------------------------------------------------
# Epoch 19 - Train loss: 0.106733, Train accuracy: 92.00%
#          - Test loss: 0.233396, Test accuracy: 74.30%
# -------------------------------------------------------------
# Epoch 20 - Train loss: 0.106098, Train accuracy: 93.33%
#          - Test loss: 0.228524, Test accuracy: 74.80%
# -------------------------------------------------------------
# Epoch 21 - Train loss: 0.101910, Train accuracy: 93.33%
#          - Test loss: 0.224914, Test accuracy: 74.40%
# -------------------------------------------------------------
# Epoch 22 - Train loss: 0.095131, Train accuracy: 94.00%
#          - Test loss: 0.221654, Test accuracy: 74.20%
# -------------------------------------------------------------
# Epoch 23 - Train loss: 0.091683, Train accuracy: 93.33%
#          - Test loss: 0.217982, Test accuracy: 74.70%
# -------------------------------------------------------------
# Epoch 24 - Train loss: 0.089356, Train accuracy: 92.67%
#          - Test loss: 0.214729, Test accuracy: 75.00%
# -------------------------------------------------------------
# Epoch 25 - Train loss: 0.084307, Train accuracy: 93.33%
#          - Test loss: 0.212266, Test accuracy: 74.80%
# -------------------------------------------------------------
# Epoch 26 - Train loss: 0.080796, Train accuracy: 93.33%
#          - Test loss: 0.209468, Test accuracy: 74.80%
# -------------------------------------------------------------
# Epoch 27 - Train loss: 0.078942, Train accuracy: 92.67%
#          - Test loss: 0.206939, Test accuracy: 75.60%
# -------------------------------------------------------------
# Epoch 28 - Train loss: 0.076594, Train accuracy: 94.00%
#          - Test loss: 0.205202, Test accuracy: 74.80%
# -------------------------------------------------------------
# Epoch 29 - Train loss: 0.073995, Train accuracy: 94.67%
#          - Test loss: 0.202845, Test accuracy: 75.00%
# -------------------------------------------------------------
# Epoch 30 - Train loss: 0.071748, Train accuracy: 94.00%
#          - Test loss: 0.200379, Test accuracy: 75.60%
# -------------------------------------------------------------
# Epoch 31 - Train loss: 0.069677, Train accuracy: 94.67%
#          - Test loss: 0.199028, Test accuracy: 75.20%
# -------------------------------------------------------------
# Epoch 32 - Train loss: 0.065957, Train accuracy: 94.00%
#          - Test loss: 0.197179, Test accuracy: 76.00%
# -------------------------------------------------------------
# Epoch 33 - Train loss: 0.064676, Train accuracy: 94.67%
#          - Test loss: 0.195488, Test accuracy: 75.50%
# -------------------------------------------------------------
# Epoch 34 - Train loss: 0.063043, Train accuracy: 94.67%
#          - Test loss: 0.193826, Test accuracy: 75.90%
# -------------------------------------------------------------
# Epoch 35 - Train loss: 0.061857, Train accuracy: 95.33%
#          - Test loss: 0.192642, Test accuracy: 75.60%
# -------------------------------------------------------------
# Epoch 36 - Train loss: 0.059744, Train accuracy: 94.67%
#          - Test loss: 0.190751, Test accuracy: 75.90%
# -------------------------------------------------------------
# Epoch 37 - Train loss: 0.059813, Train accuracy: 95.33%
#          - Test loss: 0.189669, Test accuracy: 76.20%
# -------------------------------------------------------------
# Epoch 38 - Train loss: 0.054659, Train accuracy: 94.67%
#          - Test loss: 0.188105, Test accuracy: 76.20%
# -------------------------------------------------------------
# Epoch 39 - Train loss: 0.053725, Train accuracy: 96.00%
#          - Test loss: 0.186943, Test accuracy: 76.80%
# -------------------------------------------------------------
# Epoch 40 - Train loss: 0.052685, Train accuracy: 95.33%
#          - Test loss: 0.185948, Test accuracy: 76.50%
# -------------------------------------------------------------
# Epoch 41 - Train loss: 0.051466, Train accuracy: 95.33%
#          - Test loss: 0.185117, Test accuracy: 76.10%
# -------------------------------------------------------------
# Epoch 42 - Train loss: 0.050243, Train accuracy: 95.33%
#          - Test loss: 0.183933, Test accuracy: 76.30%
# -------------------------------------------------------------
# Epoch 43 - Train loss: 0.048715, Train accuracy: 95.33%
#          - Test loss: 0.182915, Test accuracy: 76.40%
# -------------------------------------------------------------
# Epoch 44 - Train loss: 0.048807, Train accuracy: 95.33%
#          - Test loss: 0.181993, Test accuracy: 76.00%
# -------------------------------------------------------------
# Epoch 45 - Train loss: 0.046564, Train accuracy: 96.00%
#          - Test loss: 0.181243, Test accuracy: 75.90%
# -------------------------------------------------------------
# Epoch 46 - Train loss: 0.044864, Train accuracy: 95.33%
#          - Test loss: 0.180185, Test accuracy: 76.10%
# -------------------------------------------------------------
# Epoch 47 - Train loss: 0.042956, Train accuracy: 95.33%
#          - Test loss: 0.178999, Test accuracy: 76.40%
# -------------------------------------------------------------
# Epoch 48 - Train loss: 0.043537, Train accuracy: 95.33%
#          - Test loss: 0.178260, Test accuracy: 76.50%
# -------------------------------------------------------------
# Epoch 49 - Train loss: 0.042424, Train accuracy: 96.00%
#          - Test loss: 0.177855, Test accuracy: 76.10%
# -------------------------------------------------------------
# Epoch 50 - Train loss: 0.040428, Train accuracy: 95.33%
#          - Test loss: 0.176904, Test accuracy: 76.60%
# -------------------------------------------------------------
# Epoch 51 - Train loss: 0.040998, Train accuracy: 95.33%
#          - Test loss: 0.176346, Test accuracy: 76.60%
# -------------------------------------------------------------
# Epoch 52 - Train loss: 0.038648, Train accuracy: 95.33%
#          - Test loss: 0.175507, Test accuracy: 76.90%
# -------------------------------------------------------------
# Epoch 53 - Train loss: 0.038431, Train accuracy: 96.00%
#          - Test loss: 0.174942, Test accuracy: 77.10%
# -------------------------------------------------------------
# Epoch 54 - Train loss: 0.038676, Train accuracy: 95.33%
#          - Test loss: 0.174316, Test accuracy: 76.80%
# -------------------------------------------------------------
# Epoch 55 - Train loss: 0.036208, Train accuracy: 95.33%
#          - Test loss: 0.173579, Test accuracy: 77.30%
# -------------------------------------------------------------
# Epoch 56 - Train loss: 0.035318, Train accuracy: 96.00%
#          - Test loss: 0.173037, Test accuracy: 76.90%
# -------------------------------------------------------------
# Epoch 57 - Train loss: 0.035526, Train accuracy: 95.33%
#          - Test loss: 0.172524, Test accuracy: 76.80%
# -------------------------------------------------------------
# Epoch 58 - Train loss: 0.033675, Train accuracy: 95.33%
#          - Test loss: 0.172000, Test accuracy: 77.00%
# -------------------------------------------------------------
# Epoch 59 - Train loss: 0.033108, Train accuracy: 95.33%
#          - Test loss: 0.171593, Test accuracy: 77.00%
# -------------------------------------------------------------
# Epoch 60 - Train loss: 0.033023, Train accuracy: 96.00%
#          - Test loss: 0.171066, Test accuracy: 76.70%
# -------------------------------------------------------------
# Epoch 61 - Train loss: 0.033390, Train accuracy: 96.67%
#          - Test loss: 0.170617, Test accuracy: 77.00%
# -------------------------------------------------------------
# Epoch 62 - Train loss: 0.031211, Train accuracy: 96.00%
#          - Test loss: 0.170204, Test accuracy: 77.10%
# -------------------------------------------------------------
# Epoch 63 - Train loss: 0.030503, Train accuracy: 96.67%
#          - Test loss: 0.169928, Test accuracy: 77.10%
# -------------------------------------------------------------
# Epoch 64 - Train loss: 0.030833, Train accuracy: 96.00%
#          - Test loss: 0.169441, Test accuracy: 76.90%
# -------------------------------------------------------------
# Epoch 65 - Train loss: 0.029928, Train accuracy: 96.67%
#          - Test loss: 0.168961, Test accuracy: 77.00%
# -------------------------------------------------------------
# Epoch 66 - Train loss: 0.030803, Train accuracy: 96.67%
#          - Test loss: 0.168625, Test accuracy: 77.20%
# -------------------------------------------------------------
# Epoch 67 - Train loss: 0.029943, Train accuracy: 96.67%
#          - Test loss: 0.168190, Test accuracy: 77.40%
# -------------------------------------------------------------
# Epoch 68 - Train loss: 0.028462, Train accuracy: 96.67%
#          - Test loss: 0.167849, Test accuracy: 77.50%
# -------------------------------------------------------------
# Epoch 69 - Train loss: 0.027500, Train accuracy: 96.67%
#          - Test loss: 0.167379, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 70 - Train loss: 0.027687, Train accuracy: 96.67%
#          - Test loss: 0.167064, Test accuracy: 77.50%
# -------------------------------------------------------------
# Epoch 71 - Train loss: 0.027427, Train accuracy: 96.67%
#          - Test loss: 0.166813, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 72 - Train loss: 0.026560, Train accuracy: 96.00%
#          - Test loss: 0.166632, Test accuracy: 77.50%
# -------------------------------------------------------------
# Epoch 73 - Train loss: 0.026366, Train accuracy: 97.33%
#          - Test loss: 0.166325, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 74 - Train loss: 0.026883, Train accuracy: 97.33%
#          - Test loss: 0.165921, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 75 - Train loss: 0.025533, Train accuracy: 97.33%
#          - Test loss: 0.166094, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 76 - Train loss: 0.025096, Train accuracy: 97.33%
#          - Test loss: 0.166005, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 77 - Train loss: 0.025064, Train accuracy: 97.33%
#          - Test loss: 0.165760, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 78 - Train loss: 0.024608, Train accuracy: 97.33%
#          - Test loss: 0.165523, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 79 - Train loss: 0.023948, Train accuracy: 97.33%
#          - Test loss: 0.165258, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 80 - Train loss: 0.023485, Train accuracy: 97.33%
#          - Test loss: 0.165024, Test accuracy: 77.50%
# -------------------------------------------------------------
# Epoch 81 - Train loss: 0.023805, Train accuracy: 97.33%
#          - Test loss: 0.165057, Test accuracy: 77.40%
# -------------------------------------------------------------
# Epoch 82 - Train loss: 0.023995, Train accuracy: 97.33%
#          - Test loss: 0.164932, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 83 - Train loss: 0.024320, Train accuracy: 98.00%
#          - Test loss: 0.164613, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 84 - Train loss: 0.023142, Train accuracy: 98.00%
#          - Test loss: 0.164557, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 85 - Train loss: 0.022594, Train accuracy: 98.67%
#          - Test loss: 0.164530, Test accuracy: 77.40%
# -------------------------------------------------------------
# Epoch 86 - Train loss: 0.022578, Train accuracy: 98.67%
#          - Test loss: 0.164366, Test accuracy: 77.40%
# -------------------------------------------------------------
# Epoch 87 - Train loss: 0.021687, Train accuracy: 98.67%
#          - Test loss: 0.164045, Test accuracy: 77.50%
# -------------------------------------------------------------
# Epoch 88 - Train loss: 0.021950, Train accuracy: 98.00%
#          - Test loss: 0.163791, Test accuracy: 77.50%
# -------------------------------------------------------------
# Epoch 89 - Train loss: 0.022160, Train accuracy: 98.00%
#          - Test loss: 0.163511, Test accuracy: 77.50%
# -------------------------------------------------------------
# Epoch 90 - Train loss: 0.020508, Train accuracy: 98.67%
#          - Test loss: 0.163608, Test accuracy: 77.30%
# -------------------------------------------------------------
# Epoch 91 - Train loss: 0.020458, Train accuracy: 98.00%
#          - Test loss: 0.163251, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 92 - Train loss: 0.020657, Train accuracy: 98.00%
#          - Test loss: 0.163131, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 93 - Train loss: 0.019691, Train accuracy: 98.67%
#          - Test loss: 0.163133, Test accuracy: 77.90%
# -------------------------------------------------------------
# Epoch 94 - Train loss: 0.020384, Train accuracy: 98.67%
#          - Test loss: 0.162875, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 95 - Train loss: 0.020289, Train accuracy: 98.67%
#          - Test loss: 0.162799, Test accuracy: 77.30%
# -------------------------------------------------------------
# Epoch 96 - Train loss: 0.019564, Train accuracy: 98.00%
#          - Test loss: 0.162537, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 97 - Train loss: 0.019101, Train accuracy: 98.67%
#          - Test loss: 0.162531, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 98 - Train loss: 0.018930, Train accuracy: 98.67%
#          - Test loss: 0.162454, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 99 - Train loss: 0.018722, Train accuracy: 98.67%
#          - Test loss: 0.162286, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 100 - Train loss: 0.017686, Train accuracy: 98.67%
#          - Test loss: 0.162497, Test accuracy: 77.30%
# -------------------------------------------------------------

# %%
# Plotting
plot_eval_results(train_loss_epochs, test_loss_epochs, train_accuracy_epochs, test_accuracy_epochs)

# %% [markdown]
# ## Part C (10 points):
#
# Weight decay works like regularization. Set weight decay to each of the values (0.1, 1, 10) during defining the SGD optimizer (see  [SGD optimizer documentation](https://pytorch.org/docs/stable/generated/torch.optim.SGD.html) for how to do that). Plot the train/test losses and accuracies per epoch. Also report the last epoch results (loss and accuracy for both train and test) . Does weight decay help in this case?Justify the results.

# %%
for weight_decay in [0.1, 1, 10]:

    linear_svm = LinearSVM(input_size, num_classes)
    optimizer = torch.optim.SGD(linear_svm.parameters(), lr=learning_rate, weight_decay = weight_decay)

    train_loss_epochs = []
    test_loss_epochs = []
    train_accuracy_epochs = []
    test_accuracy_epochs = []

    for epoch in range(num_epochs):
      for images_batch, labels_batch in train_loader:
          optimizer.zero_grad() # Clear the gradients
          outputs = linear_svm(images_batch) # Forward pass
          loss = criterion(outputs, labels_batch) # Calculate loss
          loss.backward() # Backward pass
          optimizer.step() # Update weights


      train_accuracy, train_loss = eval(linear_svm, train_loader, criterion)
      test_accuracy, test_loss = eval(linear_svm, test_loader, criterion)

      train_loss_epochs.append(train_loss)
      test_loss_epochs.append(test_loss)

      train_accuracy_epochs.append(train_accuracy)
      test_accuracy_epochs.append(test_accuracy)



    # Plot accuracies
    print(f'For weight decay value {weight_decay}:')
    plot_eval_results(train_loss_epochs, test_loss_epochs, train_accuracy_epochs, test_accuracy_epochs)
    print(f"Final Train Loss: {train_loss}, Final Test Loss: {test_loss}")
    print(f"Final Train Accuracy: {train_accuracy}, Final Test Accuracy: {test_accuracy}")
# Out:
# For weight decay value 0.1:
# Final Train Loss: 0.04599641263484955, Final Test Loss: 0.21246119029819965
# Final Train Accuracy: 98.0, Final Test Accuracy: 77.0
# For weight decay value 1:
# Final Train Loss: 0.23829179704189302, Final Test Loss: 0.3629717268049717
# Final Train Accuracy: 90.66666666666667, Final Test Accuracy: 72.5
# For weight decay value 10:
# Final Train Loss: 0.7405490875244141, Final Test Loss: 0.780644815415144
# Final Train Accuracy: 44.666666666666664, Final Test Accuracy: 31.8

# %% [markdown]
# # Task 2: Logistic Regression for MNIST classification  (20 points).
# In this part, you are asked to implement a logistic regression model for the same MNIST classfication problem.

# %% [markdown]
# ## Part A (5 points):
# Use Cross Entropy Loss (rather than Hinge Loss) to implement logistic regression.

# %% [markdown]
# ## Part B (10 points):
# 1. Compute the accuracy on the train and test set after each epoch in the training. Plot these accuracies as a function of the epoch number.
#
# 2. Compute the cross-entropy loss on the train and test set after each epoch in the training. Plot these loss values as a function of the epoch number.
#
# 3. Report the last epoch results (including loss values and accuracies) for both train and test sets.
#
# 4. Deos the model shows significant overfitting? Or do you think there might be other factors that are more significant in the mediocre performance of the model?

# %% [markdown]
# ## Part C (5 points)
#
# Compare the results with SVM model. Does it work better, worse, or similar?

# %%
# Logistic Regression model
class LogisticRegression(nn.Module):
    def __init__(self, input_size, num_classes):
      super(LogisticRegression, self).__init__()
      self.fc = nn.Linear(input_size, num_classes, bias=True)


    def forward(self, x):
        # Flatten the image
        x= x.view(-1, input_size)
        return self.fc(x)

# %%
# Model initialization
logistic_model = LogisticRegression(input_size, num_classes)
criterion = nn.CrossEntropyLoss()  # A Multi-class version of Hinge loss
optimizer = optim.SGD(logistic_model.parameters(), lr=learning_rate)



# Train logistic regression model for MNIST classification

train_loss_epochs = []
test_loss_epochs = []
train_accuracy_epochs = []
test_accuracy_epochs = []


for epoch in range(num_epochs):
  for image, true_label_batch in train_loader:
    optimizer.zero_grad()
    outputs = logistic_model(image)
    loss = criterion(outputs, true_label_batch)

    loss.backward()
    optimizer.step()

  train_acc, train_loss = eval(logistic_model, train_loader, criterion)
  test_acc, test_loss = eval(logistic_model, test_loader, criterion)


  print(f'Epoch {epoch+1:02d} - Train loss: {train_loss:.6f}, Train accuracy: {train_acc:.2f}%')
  print(f'         - Test loss: {test_loss:.6f}, Test accuracy: {test_acc:.2f}%')
  print("-------------------------------------------------------------")

  train_loss_epochs.append(train_loss)
  test_loss_epochs.append(test_loss)

  train_accuracy_epochs.append(train_acc)
  test_accuracy_epochs.append(test_acc)
# Out:
# Epoch 01 - Train loss: 2.135401, Train accuracy: 26.67%
#          - Test loss: 2.201991, Test accuracy: 20.00%
# -------------------------------------------------------------
# Epoch 02 - Train loss: 2.019290, Train accuracy: 48.00%
#          - Test loss: 2.102243, Test accuracy: 35.90%
# -------------------------------------------------------------
# Epoch 03 - Train loss: 1.898522, Train accuracy: 55.33%
#          - Test loss: 2.014663, Test accuracy: 44.20%
# -------------------------------------------------------------
# Epoch 04 - Train loss: 1.789815, Train accuracy: 57.33%
#          - Test loss: 1.931665, Test accuracy: 48.00%
# -------------------------------------------------------------
# Epoch 05 - Train loss: 1.702651, Train accuracy: 63.33%
#          - Test loss: 1.858612, Test accuracy: 52.20%
# -------------------------------------------------------------
# Epoch 06 - Train loss: 1.621929, Train accuracy: 68.00%
#          - Test loss: 1.790266, Test accuracy: 55.40%
# -------------------------------------------------------------
# Epoch 07 - Train loss: 1.535472, Train accuracy: 73.33%
#          - Test loss: 1.725709, Test accuracy: 58.20%
# -------------------------------------------------------------
# Epoch 08 - Train loss: 1.472334, Train accuracy: 76.00%
#          - Test loss: 1.669276, Test accuracy: 60.90%
# -------------------------------------------------------------
# Epoch 09 - Train loss: 1.401576, Train accuracy: 78.00%
#          - Test loss: 1.616079, Test accuracy: 62.60%
# -------------------------------------------------------------
# Epoch 10 - Train loss: 1.355853, Train accuracy: 80.00%
#          - Test loss: 1.566574, Test accuracy: 64.20%
# -------------------------------------------------------------
# Epoch 11 - Train loss: 1.292366, Train accuracy: 80.67%
#          - Test loss: 1.523439, Test accuracy: 64.50%
# -------------------------------------------------------------
# Epoch 12 - Train loss: 1.241581, Train accuracy: 81.33%
#          - Test loss: 1.483760, Test accuracy: 65.80%
# -------------------------------------------------------------
# Epoch 13 - Train loss: 1.201473, Train accuracy: 82.00%
#          - Test loss: 1.446227, Test accuracy: 66.80%
# -------------------------------------------------------------
# Epoch 14 - Train loss: 1.154196, Train accuracy: 82.67%
#          - Test loss: 1.409444, Test accuracy: 68.50%
# -------------------------------------------------------------
# Epoch 15 - Train loss: 1.123953, Train accuracy: 84.00%
#          - Test loss: 1.378241, Test accuracy: 69.20%
# -------------------------------------------------------------
# Epoch 16 - Train loss: 1.078507, Train accuracy: 86.67%
#          - Test loss: 1.347473, Test accuracy: 70.70%
# -------------------------------------------------------------
# Epoch 17 - Train loss: 1.053192, Train accuracy: 88.67%
#          - Test loss: 1.316943, Test accuracy: 72.10%
# -------------------------------------------------------------
# Epoch 18 - Train loss: 1.027485, Train accuracy: 88.67%
#          - Test loss: 1.291054, Test accuracy: 73.30%
# -------------------------------------------------------------
# Epoch 19 - Train loss: 0.984186, Train accuracy: 90.00%
#          - Test loss: 1.266481, Test accuracy: 73.40%
# -------------------------------------------------------------
# Epoch 20 - Train loss: 0.955965, Train accuracy: 90.00%
#          - Test loss: 1.243757, Test accuracy: 74.30%
# -------------------------------------------------------------
# Epoch 21 - Train loss: 0.930709, Train accuracy: 90.00%
#          - Test loss: 1.223541, Test accuracy: 74.30%
# -------------------------------------------------------------
# Epoch 22 - Train loss: 0.896085, Train accuracy: 90.00%
#          - Test loss: 1.204010, Test accuracy: 74.60%
# -------------------------------------------------------------
# Epoch 23 - Train loss: 0.883753, Train accuracy: 90.00%
#          - Test loss: 1.185878, Test accuracy: 74.40%
# -------------------------------------------------------------
# Epoch 24 - Train loss: 0.868761, Train accuracy: 90.00%
#          - Test loss: 1.167161, Test accuracy: 75.10%
# -------------------------------------------------------------
# Epoch 25 - Train loss: 0.845636, Train accuracy: 90.00%
#          - Test loss: 1.150627, Test accuracy: 75.30%
# -------------------------------------------------------------
# Epoch 26 - Train loss: 0.837176, Train accuracy: 89.33%
#          - Test loss: 1.132982, Test accuracy: 76.30%
# -------------------------------------------------------------
# Epoch 27 - Train loss: 0.811620, Train accuracy: 89.33%
#          - Test loss: 1.118349, Test accuracy: 76.20%
# -------------------------------------------------------------
# Epoch 28 - Train loss: 0.778043, Train accuracy: 90.67%
#          - Test loss: 1.103306, Test accuracy: 76.40%
# -------------------------------------------------------------
# Epoch 29 - Train loss: 0.767061, Train accuracy: 92.00%
#          - Test loss: 1.088943, Test accuracy: 76.70%
# -------------------------------------------------------------
# Epoch 30 - Train loss: 0.738663, Train accuracy: 92.00%
#          - Test loss: 1.075900, Test accuracy: 76.80%
# -------------------------------------------------------------
# Epoch 31 - Train loss: 0.738577, Train accuracy: 92.00%
#          - Test loss: 1.063242, Test accuracy: 77.40%
# -------------------------------------------------------------
# Epoch 32 - Train loss: 0.711903, Train accuracy: 92.00%
#          - Test loss: 1.052521, Test accuracy: 77.10%
# -------------------------------------------------------------
# Epoch 33 - Train loss: 0.707078, Train accuracy: 93.33%
#          - Test loss: 1.041167, Test accuracy: 77.50%
# -------------------------------------------------------------
# Epoch 34 - Train loss: 0.706024, Train accuracy: 93.33%
#          - Test loss: 1.029804, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 35 - Train loss: 0.674725, Train accuracy: 93.33%
#          - Test loss: 1.019977, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 36 - Train loss: 0.667029, Train accuracy: 93.33%
#          - Test loss: 1.010931, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 37 - Train loss: 0.658035, Train accuracy: 93.33%
#          - Test loss: 1.001646, Test accuracy: 77.50%
# -------------------------------------------------------------
# Epoch 38 - Train loss: 0.643322, Train accuracy: 93.33%
#          - Test loss: 0.991936, Test accuracy: 78.00%
# -------------------------------------------------------------
# Epoch 39 - Train loss: 0.630251, Train accuracy: 93.33%
#          - Test loss: 0.984026, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 40 - Train loss: 0.622586, Train accuracy: 93.33%
#          - Test loss: 0.975095, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 41 - Train loss: 0.601474, Train accuracy: 93.33%
#          - Test loss: 0.967732, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 42 - Train loss: 0.599184, Train accuracy: 93.33%
#          - Test loss: 0.960868, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 43 - Train loss: 0.592419, Train accuracy: 93.33%
#          - Test loss: 0.953015, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 44 - Train loss: 0.574452, Train accuracy: 93.33%
#          - Test loss: 0.946427, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 45 - Train loss: 0.581528, Train accuracy: 93.33%
#          - Test loss: 0.939524, Test accuracy: 77.90%
# -------------------------------------------------------------
# Epoch 46 - Train loss: 0.568248, Train accuracy: 93.33%
#          - Test loss: 0.933458, Test accuracy: 77.90%
# -------------------------------------------------------------
# Epoch 47 - Train loss: 0.558445, Train accuracy: 93.33%
#          - Test loss: 0.927435, Test accuracy: 78.20%
# -------------------------------------------------------------
# Epoch 48 - Train loss: 0.543888, Train accuracy: 93.33%
#          - Test loss: 0.921726, Test accuracy: 78.20%
# -------------------------------------------------------------
# Epoch 49 - Train loss: 0.544731, Train accuracy: 94.00%
#          - Test loss: 0.917377, Test accuracy: 78.00%
# -------------------------------------------------------------
# Epoch 50 - Train loss: 0.538080, Train accuracy: 94.67%
#          - Test loss: 0.911502, Test accuracy: 78.10%
# -------------------------------------------------------------
# Epoch 51 - Train loss: 0.516217, Train accuracy: 94.67%
#          - Test loss: 0.905293, Test accuracy: 78.10%
# -------------------------------------------------------------
# Epoch 52 - Train loss: 0.504561, Train accuracy: 94.67%
#          - Test loss: 0.899710, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 53 - Train loss: 0.503838, Train accuracy: 94.67%
#          - Test loss: 0.894689, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 54 - Train loss: 0.503740, Train accuracy: 94.67%
#          - Test loss: 0.890337, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 55 - Train loss: 0.496411, Train accuracy: 94.67%
#          - Test loss: 0.885277, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 56 - Train loss: 0.483547, Train accuracy: 94.67%
#          - Test loss: 0.879889, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 57 - Train loss: 0.489626, Train accuracy: 94.67%
#          - Test loss: 0.875716, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 58 - Train loss: 0.475230, Train accuracy: 94.67%
#          - Test loss: 0.872143, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 59 - Train loss: 0.470953, Train accuracy: 94.67%
#          - Test loss: 0.867705, Test accuracy: 78.10%
# -------------------------------------------------------------
# Epoch 60 - Train loss: 0.473514, Train accuracy: 94.67%
#          - Test loss: 0.864110, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 61 - Train loss: 0.464554, Train accuracy: 94.67%
#          - Test loss: 0.860292, Test accuracy: 78.00%
# -------------------------------------------------------------
# Epoch 62 - Train loss: 0.459224, Train accuracy: 94.67%
#          - Test loss: 0.856396, Test accuracy: 78.30%
# -------------------------------------------------------------
# Epoch 63 - Train loss: 0.451842, Train accuracy: 95.33%
#          - Test loss: 0.852834, Test accuracy: 78.40%
# -------------------------------------------------------------
# Epoch 64 - Train loss: 0.438214, Train accuracy: 95.33%
#          - Test loss: 0.849462, Test accuracy: 78.30%
# -------------------------------------------------------------
# Epoch 65 - Train loss: 0.441163, Train accuracy: 95.33%
#          - Test loss: 0.845698, Test accuracy: 78.40%
# -------------------------------------------------------------
# Epoch 66 - Train loss: 0.437213, Train accuracy: 95.33%
#          - Test loss: 0.841689, Test accuracy: 78.50%
# -------------------------------------------------------------
# Epoch 67 - Train loss: 0.428480, Train accuracy: 95.33%
#          - Test loss: 0.837871, Test accuracy: 78.60%
# -------------------------------------------------------------
# Epoch 68 - Train loss: 0.422501, Train accuracy: 94.67%
#          - Test loss: 0.833856, Test accuracy: 78.70%
# -------------------------------------------------------------
# Epoch 69 - Train loss: 0.411419, Train accuracy: 94.67%
#          - Test loss: 0.830333, Test accuracy: 78.40%
# -------------------------------------------------------------
# Epoch 70 - Train loss: 0.414497, Train accuracy: 96.00%
#          - Test loss: 0.828158, Test accuracy: 78.60%
# -------------------------------------------------------------
# Epoch 71 - Train loss: 0.407010, Train accuracy: 96.00%
#          - Test loss: 0.826025, Test accuracy: 78.60%
# -------------------------------------------------------------
# Epoch 72 - Train loss: 0.410329, Train accuracy: 96.67%
#          - Test loss: 0.824081, Test accuracy: 78.20%
# -------------------------------------------------------------
# Epoch 73 - Train loss: 0.392254, Train accuracy: 96.67%
#          - Test loss: 0.821356, Test accuracy: 78.10%
# -------------------------------------------------------------
# Epoch 74 - Train loss: 0.399573, Train accuracy: 96.67%
#          - Test loss: 0.818986, Test accuracy: 78.10%
# -------------------------------------------------------------
# Epoch 75 - Train loss: 0.392457, Train accuracy: 96.67%
#          - Test loss: 0.815987, Test accuracy: 78.60%
# -------------------------------------------------------------
# Epoch 76 - Train loss: 0.381197, Train accuracy: 96.00%
#          - Test loss: 0.814064, Test accuracy: 78.50%
# -------------------------------------------------------------
# Epoch 77 - Train loss: 0.384336, Train accuracy: 96.67%
#          - Test loss: 0.812583, Test accuracy: 78.10%
# -------------------------------------------------------------
# Epoch 78 - Train loss: 0.381832, Train accuracy: 96.67%
#          - Test loss: 0.809984, Test accuracy: 78.20%
# -------------------------------------------------------------
# Epoch 79 - Train loss: 0.375519, Train accuracy: 96.67%
#          - Test loss: 0.806759, Test accuracy: 78.50%
# -------------------------------------------------------------
# Epoch 80 - Train loss: 0.370461, Train accuracy: 96.00%
#          - Test loss: 0.804643, Test accuracy: 78.80%
# -------------------------------------------------------------
# Epoch 81 - Train loss: 0.362673, Train accuracy: 96.67%
#          - Test loss: 0.803298, Test accuracy: 78.20%
# -------------------------------------------------------------
# Epoch 82 - Train loss: 0.363641, Train accuracy: 96.67%
#          - Test loss: 0.801420, Test accuracy: 78.40%
# -------------------------------------------------------------
# Epoch 83 - Train loss: 0.360558, Train accuracy: 96.67%
#          - Test loss: 0.799091, Test accuracy: 78.40%
# -------------------------------------------------------------
# Epoch 84 - Train loss: 0.362123, Train accuracy: 98.00%
#          - Test loss: 0.797009, Test accuracy: 78.40%
# -------------------------------------------------------------
# Epoch 85 - Train loss: 0.351563, Train accuracy: 98.00%
#          - Test loss: 0.794705, Test accuracy: 78.20%
# -------------------------------------------------------------
# Epoch 86 - Train loss: 0.345513, Train accuracy: 98.00%
#          - Test loss: 0.792413, Test accuracy: 78.50%
# -------------------------------------------------------------
# Epoch 87 - Train loss: 0.345683, Train accuracy: 98.00%
#          - Test loss: 0.790587, Test accuracy: 78.70%
# -------------------------------------------------------------
# Epoch 88 - Train loss: 0.352555, Train accuracy: 98.00%
#          - Test loss: 0.787631, Test accuracy: 78.60%
# -------------------------------------------------------------
# Epoch 89 - Train loss: 0.336301, Train accuracy: 98.00%
#          - Test loss: 0.785630, Test accuracy: 78.50%
# -------------------------------------------------------------
# Epoch 90 - Train loss: 0.346753, Train accuracy: 98.00%
#          - Test loss: 0.784186, Test accuracy: 78.50%
# -------------------------------------------------------------
# Epoch 91 - Train loss: 0.337509, Train accuracy: 98.00%
#          - Test loss: 0.782908, Test accuracy: 78.30%
# -------------------------------------------------------------
# Epoch 92 - Train loss: 0.332457, Train accuracy: 98.00%
#          - Test loss: 0.781639, Test accuracy: 78.40%
# -------------------------------------------------------------
# Epoch 93 - Train loss: 0.326524, Train accuracy: 98.00%
#          - Test loss: 0.780330, Test accuracy: 78.30%
# -------------------------------------------------------------
# Epoch 94 - Train loss: 0.320918, Train accuracy: 98.00%
#          - Test loss: 0.777999, Test accuracy: 78.30%
# -------------------------------------------------------------
# Epoch 95 - Train loss: 0.322172, Train accuracy: 98.00%
#          - Test loss: 0.777311, Test accuracy: 78.30%
# -------------------------------------------------------------
# Epoch 96 - Train loss: 0.318894, Train accuracy: 98.00%
#          - Test loss: 0.775506, Test accuracy: 78.30%
# -------------------------------------------------------------
# Epoch 97 - Train loss: 0.318687, Train accuracy: 98.00%
#          - Test loss: 0.773395, Test accuracy: 78.50%
# -------------------------------------------------------------
# Epoch 98 - Train loss: 0.313672, Train accuracy: 98.00%
#          - Test loss: 0.771730, Test accuracy: 78.40%
# -------------------------------------------------------------
# Epoch 99 - Train loss: 0.308133, Train accuracy: 98.00%
#          - Test loss: 0.769989, Test accuracy: 78.50%
# -------------------------------------------------------------
# Epoch 100 - Train loss: 0.307558, Train accuracy: 98.67%
#          - Test loss: 0.769066, Test accuracy: 78.60%
# -------------------------------------------------------------

# %%
# Plot the loss values and accuracies for train/test
plot_eval_results(train_loss_epochs, test_loss_epochs, train_accuracy_epochs, test_accuracy_epochs)

# %% [markdown]
# # Task 3: Non-linearity (30 points)

# %% [markdown]
# ## Part A (20 points):
#
# Add a hidden layer with 5000 neurons and a RELU layer for both logistic regression and SVM models in Task 1 and Task 2.
# 1. For both models, plot the train loss and the test loss.
# 2. For both models, plot the train and test accuracies.
# 3. For both models, report the loss and accuracy for both train and test sets.

# %% [markdown]
# ## Part B (10 Points):
#
# Compare the results with the linear model (without weight decay, to keep the comparison fair). Which approach works better? Why? Which appproach is more prone to overfitting? Explain your findings and justify it.

# %%
# Both the SVM and Logistic Regression models we have in Task 1 and 2
# can be changed to the ModifiedModel below.

# Modified model with added neurons and relu layer
class ModifiedModel(nn.Module):
    def __init__(self, input_size, num_classes):
      super(ModifiedModel, self).__init__()
      self.hidden_size = 5000
      self.fc1 = nn.Linear(input_size, self.hidden_size) # input maps to 5000 neurons
      self.fc2 = nn.Linear(self.hidden_size, num_classes) # 5000 mapped to our 10 digit for classification
      self.relu = nn.ReLU() # activation function



    def forward(self, x):
        # Flatten the image
        x = x.view(-1, input_size)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# Run the ModifiedModel with Hinge Loss (SVM)
# Model initialization

modified_SVM = ModifiedModel(input_size, num_classes)
criterion = nn.MultiMarginLoss()
optimizer = optim.SGD(modified_SVM.parameters(), lr= learning_rate)

train_loss_epochs = []
test_loss_epochs = []
train_accuracy_epochs = []
test_accuracy_epochs = []


for epoch in range(num_epochs):
  for image, true_label_batch in train_loader:
    optimizer.zero_grad()
    outputs = modified_SVM(image)
    loss = criterion(outputs, true_label_batch)

    loss.backward()
    optimizer.step()

  train_acc, train_loss = eval(modified_SVM, train_loader, criterion)
  test_acc, test_loss = eval(modified_SVM, test_loader, criterion)


  print(f'Epoch {epoch+1:02d} - Train loss: {train_loss:.6f}, Train accuracy: {train_acc:.2f}%')
  print(f'         - Test loss: {test_loss:.6f}, Test accuracy: {test_acc:.2f}%')
  print("-------------------------------------------------------------")

  train_loss_epochs.append(train_loss)
  test_loss_epochs.append(test_loss)

  train_accuracy_epochs.append(train_acc)
  test_accuracy_epochs.append(test_acc)
# Out:
# Epoch 01 - Train loss: 0.745862, Train accuracy: 27.33%
#          - Test loss: 0.795555, Test accuracy: 21.00%
# -------------------------------------------------------------
# Epoch 02 - Train loss: 0.617987, Train accuracy: 46.00%
#          - Test loss: 0.705705, Test accuracy: 32.60%
# -------------------------------------------------------------
# Epoch 03 - Train loss: 0.523564, Train accuracy: 51.33%
#          - Test loss: 0.628257, Test accuracy: 37.90%
# -------------------------------------------------------------
# Epoch 04 - Train loss: 0.439884, Train accuracy: 61.33%
#          - Test loss: 0.563869, Test accuracy: 45.70%
# -------------------------------------------------------------
# Epoch 05 - Train loss: 0.371727, Train accuracy: 67.33%
#          - Test loss: 0.500815, Test accuracy: 55.40%
# -------------------------------------------------------------
# Epoch 06 - Train loss: 0.318151, Train accuracy: 74.67%
#          - Test loss: 0.449028, Test accuracy: 57.60%
# -------------------------------------------------------------
# Epoch 07 - Train loss: 0.259547, Train accuracy: 80.67%
#          - Test loss: 0.404939, Test accuracy: 62.90%
# -------------------------------------------------------------
# Epoch 08 - Train loss: 0.226151, Train accuracy: 88.67%
#          - Test loss: 0.368548, Test accuracy: 68.50%
# -------------------------------------------------------------
# Epoch 09 - Train loss: 0.196645, Train accuracy: 88.67%
#          - Test loss: 0.343371, Test accuracy: 67.40%
# -------------------------------------------------------------
# Epoch 10 - Train loss: 0.181540, Train accuracy: 92.67%
#          - Test loss: 0.320415, Test accuracy: 73.20%
# -------------------------------------------------------------
# Epoch 11 - Train loss: 0.157070, Train accuracy: 94.00%
#          - Test loss: 0.302134, Test accuracy: 74.30%
# -------------------------------------------------------------
# Epoch 12 - Train loss: 0.148055, Train accuracy: 94.67%
#          - Test loss: 0.288788, Test accuracy: 75.30%
# -------------------------------------------------------------
# Epoch 13 - Train loss: 0.137169, Train accuracy: 95.33%
#          - Test loss: 0.279796, Test accuracy: 75.40%
# -------------------------------------------------------------
# Epoch 14 - Train loss: 0.125512, Train accuracy: 94.67%
#          - Test loss: 0.269395, Test accuracy: 76.00%
# -------------------------------------------------------------
# Epoch 15 - Train loss: 0.116654, Train accuracy: 94.67%
#          - Test loss: 0.261562, Test accuracy: 76.00%
# -------------------------------------------------------------
# Epoch 16 - Train loss: 0.105747, Train accuracy: 94.00%
#          - Test loss: 0.255407, Test accuracy: 73.70%
# -------------------------------------------------------------
# Epoch 17 - Train loss: 0.096832, Train accuracy: 95.33%
#          - Test loss: 0.245855, Test accuracy: 77.20%
# -------------------------------------------------------------
# Epoch 18 - Train loss: 0.092588, Train accuracy: 94.67%
#          - Test loss: 0.241828, Test accuracy: 76.70%
# -------------------------------------------------------------
# Epoch 19 - Train loss: 0.084851, Train accuracy: 96.00%
#          - Test loss: 0.235656, Test accuracy: 77.50%
# -------------------------------------------------------------
# Epoch 20 - Train loss: 0.079669, Train accuracy: 96.00%
#          - Test loss: 0.232403, Test accuracy: 77.10%
# -------------------------------------------------------------
# Epoch 21 - Train loss: 0.076485, Train accuracy: 96.00%
#          - Test loss: 0.228341, Test accuracy: 76.70%
# -------------------------------------------------------------
# Epoch 22 - Train loss: 0.070422, Train accuracy: 96.00%
#          - Test loss: 0.224016, Test accuracy: 77.10%
# -------------------------------------------------------------
# Epoch 23 - Train loss: 0.068153, Train accuracy: 96.67%
#          - Test loss: 0.221710, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 24 - Train loss: 0.063559, Train accuracy: 96.67%
#          - Test loss: 0.218662, Test accuracy: 77.90%
# -------------------------------------------------------------
# Epoch 25 - Train loss: 0.060113, Train accuracy: 96.67%
#          - Test loss: 0.215211, Test accuracy: 77.30%
# -------------------------------------------------------------
# Epoch 26 - Train loss: 0.056472, Train accuracy: 97.33%
#          - Test loss: 0.211918, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 27 - Train loss: 0.054896, Train accuracy: 97.33%
#          - Test loss: 0.210131, Test accuracy: 77.40%
# -------------------------------------------------------------
# Epoch 28 - Train loss: 0.054975, Train accuracy: 97.33%
#          - Test loss: 0.207433, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 29 - Train loss: 0.050511, Train accuracy: 97.33%
#          - Test loss: 0.205553, Test accuracy: 78.00%
# -------------------------------------------------------------
# Epoch 30 - Train loss: 0.049326, Train accuracy: 98.00%
#          - Test loss: 0.203081, Test accuracy: 78.00%
# -------------------------------------------------------------
# Epoch 31 - Train loss: 0.046432, Train accuracy: 98.00%
#          - Test loss: 0.201317, Test accuracy: 77.90%
# -------------------------------------------------------------
# Epoch 32 - Train loss: 0.045283, Train accuracy: 98.00%
#          - Test loss: 0.199324, Test accuracy: 78.00%
# -------------------------------------------------------------
# Epoch 33 - Train loss: 0.042069, Train accuracy: 98.00%
#          - Test loss: 0.197402, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 34 - Train loss: 0.039876, Train accuracy: 98.00%
#          - Test loss: 0.196051, Test accuracy: 77.90%
# -------------------------------------------------------------
# Epoch 35 - Train loss: 0.038736, Train accuracy: 98.00%
#          - Test loss: 0.194477, Test accuracy: 78.10%
# -------------------------------------------------------------
# Epoch 36 - Train loss: 0.038672, Train accuracy: 98.00%
#          - Test loss: 0.193587, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 37 - Train loss: 0.038219, Train accuracy: 98.00%
#          - Test loss: 0.191890, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 38 - Train loss: 0.035594, Train accuracy: 98.00%
#          - Test loss: 0.190777, Test accuracy: 78.30%
# -------------------------------------------------------------
# Epoch 39 - Train loss: 0.033407, Train accuracy: 98.00%
#          - Test loss: 0.189569, Test accuracy: 78.40%
# -------------------------------------------------------------
# Epoch 40 - Train loss: 0.033869, Train accuracy: 98.00%
#          - Test loss: 0.188726, Test accuracy: 78.40%
# -------------------------------------------------------------
# Epoch 41 - Train loss: 0.030717, Train accuracy: 98.00%
#          - Test loss: 0.187677, Test accuracy: 78.20%
# -------------------------------------------------------------
# Epoch 42 - Train loss: 0.030920, Train accuracy: 98.00%
#          - Test loss: 0.187302, Test accuracy: 78.60%
# -------------------------------------------------------------
# Epoch 43 - Train loss: 0.028683, Train accuracy: 98.00%
#          - Test loss: 0.186428, Test accuracy: 78.60%
# -------------------------------------------------------------
# Epoch 44 - Train loss: 0.028371, Train accuracy: 98.67%
#          - Test loss: 0.184932, Test accuracy: 78.50%
# -------------------------------------------------------------
# Epoch 45 - Train loss: 0.027708, Train accuracy: 98.00%
#          - Test loss: 0.184366, Test accuracy: 78.30%
# -------------------------------------------------------------
# Epoch 46 - Train loss: 0.027381, Train accuracy: 99.33%
#          - Test loss: 0.183898, Test accuracy: 78.40%
# -------------------------------------------------------------
# Epoch 47 - Train loss: 0.025498, Train accuracy: 98.67%
#          - Test loss: 0.183040, Test accuracy: 78.30%
# -------------------------------------------------------------
# Epoch 48 - Train loss: 0.025642, Train accuracy: 99.33%
#          - Test loss: 0.182372, Test accuracy: 78.60%
# -------------------------------------------------------------
# Epoch 49 - Train loss: 0.024938, Train accuracy: 99.33%
#          - Test loss: 0.182129, Test accuracy: 78.70%
# -------------------------------------------------------------
# Epoch 50 - Train loss: 0.023946, Train accuracy: 99.33%
#          - Test loss: 0.181314, Test accuracy: 78.70%
# -------------------------------------------------------------
# Epoch 51 - Train loss: 0.022737, Train accuracy: 99.33%
#          - Test loss: 0.180790, Test accuracy: 79.30%
# -------------------------------------------------------------
# Epoch 52 - Train loss: 0.023574, Train accuracy: 99.33%
#          - Test loss: 0.180160, Test accuracy: 79.00%
# -------------------------------------------------------------
# Epoch 53 - Train loss: 0.022533, Train accuracy: 99.33%
#          - Test loss: 0.180004, Test accuracy: 79.00%
# -------------------------------------------------------------
# Epoch 54 - Train loss: 0.021896, Train accuracy: 99.33%
#          - Test loss: 0.179623, Test accuracy: 79.20%
# -------------------------------------------------------------
# Epoch 55 - Train loss: 0.020384, Train accuracy: 99.33%
#          - Test loss: 0.178932, Test accuracy: 79.20%
# -------------------------------------------------------------
# Epoch 56 - Train loss: 0.019576, Train accuracy: 99.33%
#          - Test loss: 0.178701, Test accuracy: 79.40%
# -------------------------------------------------------------
# Epoch 57 - Train loss: 0.019699, Train accuracy: 99.33%
#          - Test loss: 0.178208, Test accuracy: 79.30%
# -------------------------------------------------------------
# Epoch 58 - Train loss: 0.018451, Train accuracy: 99.33%
#          - Test loss: 0.178029, Test accuracy: 79.70%
# -------------------------------------------------------------
# Epoch 59 - Train loss: 0.018536, Train accuracy: 99.33%
#          - Test loss: 0.177862, Test accuracy: 79.40%
# -------------------------------------------------------------
# Epoch 60 - Train loss: 0.018257, Train accuracy: 99.33%
#          - Test loss: 0.177159, Test accuracy: 79.30%
# -------------------------------------------------------------
# Epoch 61 - Train loss: 0.017678, Train accuracy: 99.33%
#          - Test loss: 0.177236, Test accuracy: 79.50%
# -------------------------------------------------------------
# Epoch 62 - Train loss: 0.017401, Train accuracy: 100.00%
#          - Test loss: 0.176870, Test accuracy: 79.70%
# -------------------------------------------------------------
# Epoch 63 - Train loss: 0.016825, Train accuracy: 99.33%
#          - Test loss: 0.176185, Test accuracy: 79.30%
# -------------------------------------------------------------
# Epoch 64 - Train loss: 0.016988, Train accuracy: 100.00%
#          - Test loss: 0.176591, Test accuracy: 79.30%
# -------------------------------------------------------------
# Epoch 65 - Train loss: 0.016453, Train accuracy: 100.00%
#          - Test loss: 0.175905, Test accuracy: 79.60%
# -------------------------------------------------------------
# Epoch 66 - Train loss: 0.015187, Train accuracy: 100.00%
#          - Test loss: 0.175848, Test accuracy: 79.50%
# -------------------------------------------------------------
# Epoch 67 - Train loss: 0.014724, Train accuracy: 100.00%
#          - Test loss: 0.175375, Test accuracy: 79.70%
# -------------------------------------------------------------
# Epoch 68 - Train loss: 0.014772, Train accuracy: 100.00%
#          - Test loss: 0.175116, Test accuracy: 79.50%
# -------------------------------------------------------------
# Epoch 69 - Train loss: 0.014989, Train accuracy: 100.00%
#          - Test loss: 0.174858, Test accuracy: 79.50%
# -------------------------------------------------------------
# Epoch 70 - Train loss: 0.013698, Train accuracy: 100.00%
#          - Test loss: 0.174676, Test accuracy: 79.40%
# -------------------------------------------------------------
# Epoch 71 - Train loss: 0.014497, Train accuracy: 100.00%
#          - Test loss: 0.174651, Test accuracy: 79.30%
# -------------------------------------------------------------
# Epoch 72 - Train loss: 0.013642, Train accuracy: 100.00%
#          - Test loss: 0.174057, Test accuracy: 79.40%
# -------------------------------------------------------------
# Epoch 73 - Train loss: 0.013110, Train accuracy: 100.00%
#          - Test loss: 0.174082, Test accuracy: 79.60%
# -------------------------------------------------------------
# Epoch 74 - Train loss: 0.013219, Train accuracy: 100.00%
#          - Test loss: 0.173854, Test accuracy: 79.70%
# -------------------------------------------------------------
# Epoch 75 - Train loss: 0.012999, Train accuracy: 100.00%
#          - Test loss: 0.173895, Test accuracy: 79.30%
# -------------------------------------------------------------
# Epoch 76 - Train loss: 0.013234, Train accuracy: 100.00%
#          - Test loss: 0.173207, Test accuracy: 79.40%
# -------------------------------------------------------------
# Epoch 77 - Train loss: 0.011980, Train accuracy: 100.00%
#          - Test loss: 0.173525, Test accuracy: 79.20%
# -------------------------------------------------------------
# Epoch 78 - Train loss: 0.012006, Train accuracy: 100.00%
#          - Test loss: 0.172666, Test accuracy: 79.50%
# -------------------------------------------------------------
# Epoch 79 - Train loss: 0.011202, Train accuracy: 100.00%
#          - Test loss: 0.172752, Test accuracy: 79.70%
# -------------------------------------------------------------
# Epoch 80 - Train loss: 0.011802, Train accuracy: 100.00%
#          - Test loss: 0.172752, Test accuracy: 79.60%
# -------------------------------------------------------------
# Epoch 81 - Train loss: 0.011469, Train accuracy: 100.00%
#          - Test loss: 0.172616, Test accuracy: 79.70%
# -------------------------------------------------------------
# Epoch 82 - Train loss: 0.011374, Train accuracy: 100.00%
#          - Test loss: 0.172275, Test accuracy: 79.40%
# -------------------------------------------------------------
# Epoch 83 - Train loss: 0.010443, Train accuracy: 100.00%
#          - Test loss: 0.171977, Test accuracy: 79.60%
# -------------------------------------------------------------
# Epoch 84 - Train loss: 0.010747, Train accuracy: 100.00%
#          - Test loss: 0.172381, Test accuracy: 79.70%
# -------------------------------------------------------------
# Epoch 85 - Train loss: 0.010996, Train accuracy: 100.00%
#          - Test loss: 0.171792, Test accuracy: 79.60%
# -------------------------------------------------------------
# Epoch 86 - Train loss: 0.009711, Train accuracy: 100.00%
#          - Test loss: 0.171737, Test accuracy: 79.50%
# -------------------------------------------------------------
# Epoch 87 - Train loss: 0.010088, Train accuracy: 100.00%
#          - Test loss: 0.171814, Test accuracy: 79.60%
# -------------------------------------------------------------
# Epoch 88 - Train loss: 0.009891, Train accuracy: 100.00%
#          - Test loss: 0.171828, Test accuracy: 79.30%
# -------------------------------------------------------------
# Epoch 89 - Train loss: 0.009785, Train accuracy: 100.00%
#          - Test loss: 0.171162, Test accuracy: 79.40%
# -------------------------------------------------------------
# Epoch 90 - Train loss: 0.010003, Train accuracy: 100.00%
#          - Test loss: 0.171215, Test accuracy: 79.60%
# -------------------------------------------------------------
# Epoch 91 - Train loss: 0.009325, Train accuracy: 100.00%
#          - Test loss: 0.171104, Test accuracy: 79.60%
# -------------------------------------------------------------
# Epoch 92 - Train loss: 0.008819, Train accuracy: 100.00%
#          - Test loss: 0.171012, Test accuracy: 79.50%
# -------------------------------------------------------------
# Epoch 93 - Train loss: 0.008781, Train accuracy: 100.00%
#          - Test loss: 0.170993, Test accuracy: 79.60%
# -------------------------------------------------------------
# Epoch 94 - Train loss: 0.008418, Train accuracy: 100.00%
#          - Test loss: 0.170722, Test accuracy: 79.70%
# -------------------------------------------------------------
# Epoch 95 - Train loss: 0.009143, Train accuracy: 100.00%
#          - Test loss: 0.171116, Test accuracy: 79.50%
# -------------------------------------------------------------
# Epoch 96 - Train loss: 0.008682, Train accuracy: 100.00%
#          - Test loss: 0.170769, Test accuracy: 79.50%
# -------------------------------------------------------------
# Epoch 97 - Train loss: 0.008268, Train accuracy: 100.00%
#          - Test loss: 0.170520, Test accuracy: 79.70%
# -------------------------------------------------------------
# Epoch 98 - Train loss: 0.008062, Train accuracy: 100.00%
#          - Test loss: 0.170575, Test accuracy: 79.60%
# -------------------------------------------------------------
# Epoch 99 - Train loss: 0.007779, Train accuracy: 100.00%
#          - Test loss: 0.170263, Test accuracy: 79.60%
# -------------------------------------------------------------
# Epoch 100 - Train loss: 0.007732, Train accuracy: 100.00%
#          - Test loss: 0.170310, Test accuracy: 79.60%
# -------------------------------------------------------------

# %%
# Plot the loss values and accuracies for train/test
plot_eval_results(train_loss_epochs, test_loss_epochs, train_accuracy_epochs, test_accuracy_epochs)

# %%
# Run the ModifiedModel with Cross Entropy Loss (Logistic Regression)
# Model initialization

modified_logistic_regression_model = ModifiedModel(input_size, num_classes)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(modified_logistic_regression_model.parameters(), lr= learning_rate)

train_loss_epochs = []
test_loss_epochs = []
train_accuracy_epochs = []
test_accuracy_epochs = []

for epoch in range(num_epochs):
  for image, true_label_batch in train_loader:
    optimizer.zero_grad()
    outputs = modified_logistic_regression_model(image)
    loss = criterion(outputs, true_label_batch)
    loss.backward()
    optimizer.step()

  train_acc, train_loss = eval(modified_logistic_regression_model, train_loader, criterion)
  test_acc, test_loss = eval(modified_logistic_regression_model, test_loader, criterion)


  print(f'Epoch {epoch+1:02d} - Train loss: {train_loss:.6f}, Train accuracy: {train_acc:.2f}%')
  print(f'         - Test loss: {test_loss:.6f}, Test accuracy: {test_acc:.2f}%')
  print("-------------------------------------------------------------")

  train_loss_epochs.append(train_loss)
  test_loss_epochs.append(test_loss)

  train_accuracy_epochs.append(train_acc)
  test_accuracy_epochs.append(test_acc)
# Out:
# Epoch 01 - Train loss: 2.163518, Train accuracy: 38.67%
#          - Test loss: 2.210944, Test accuracy: 29.70%
# -------------------------------------------------------------
# Epoch 02 - Train loss: 2.039067, Train accuracy: 46.67%
#          - Test loss: 2.127980, Test accuracy: 35.30%
# -------------------------------------------------------------
# Epoch 03 - Train loss: 1.932415, Train accuracy: 52.00%
#          - Test loss: 2.049023, Test accuracy: 39.80%
# -------------------------------------------------------------
# Epoch 04 - Train loss: 1.829838, Train accuracy: 61.33%
#          - Test loss: 1.969245, Test accuracy: 50.20%
# -------------------------------------------------------------
# Epoch 05 - Train loss: 1.733451, Train accuracy: 65.33%
#          - Test loss: 1.893463, Test accuracy: 53.70%
# -------------------------------------------------------------
# Epoch 06 - Train loss: 1.643435, Train accuracy: 63.33%
#          - Test loss: 1.831600, Test accuracy: 52.40%
# -------------------------------------------------------------
# Epoch 07 - Train loss: 1.563379, Train accuracy: 68.67%
#          - Test loss: 1.765032, Test accuracy: 54.70%
# -------------------------------------------------------------
# Epoch 08 - Train loss: 1.498823, Train accuracy: 74.00%
#          - Test loss: 1.700217, Test accuracy: 59.70%
# -------------------------------------------------------------
# Epoch 09 - Train loss: 1.415424, Train accuracy: 78.00%
#          - Test loss: 1.636122, Test accuracy: 62.60%
# -------------------------------------------------------------
# Epoch 10 - Train loss: 1.338483, Train accuracy: 82.00%
#          - Test loss: 1.583120, Test accuracy: 64.30%
# -------------------------------------------------------------
# Epoch 11 - Train loss: 1.280500, Train accuracy: 83.33%
#          - Test loss: 1.530424, Test accuracy: 64.80%
# -------------------------------------------------------------
# Epoch 12 - Train loss: 1.202577, Train accuracy: 85.33%
#          - Test loss: 1.480950, Test accuracy: 67.60%
# -------------------------------------------------------------
# Epoch 13 - Train loss: 1.151861, Train accuracy: 87.33%
#          - Test loss: 1.436004, Test accuracy: 68.40%
# -------------------------------------------------------------
# Epoch 14 - Train loss: 1.094646, Train accuracy: 85.33%
#          - Test loss: 1.396686, Test accuracy: 66.70%
# -------------------------------------------------------------
# Epoch 15 - Train loss: 1.049194, Train accuracy: 88.00%
#          - Test loss: 1.350859, Test accuracy: 70.50%
# -------------------------------------------------------------
# Epoch 16 - Train loss: 1.007753, Train accuracy: 88.67%
#          - Test loss: 1.311660, Test accuracy: 71.10%
# -------------------------------------------------------------
# Epoch 17 - Train loss: 0.965251, Train accuracy: 90.00%
#          - Test loss: 1.273553, Test accuracy: 72.70%
# -------------------------------------------------------------
# Epoch 18 - Train loss: 0.921251, Train accuracy: 90.00%
#          - Test loss: 1.242243, Test accuracy: 73.50%
# -------------------------------------------------------------
# Epoch 19 - Train loss: 0.892013, Train accuracy: 91.33%
#          - Test loss: 1.210982, Test accuracy: 73.90%
# -------------------------------------------------------------
# Epoch 20 - Train loss: 0.853871, Train accuracy: 91.33%
#          - Test loss: 1.183229, Test accuracy: 74.40%
# -------------------------------------------------------------
# Epoch 21 - Train loss: 0.810994, Train accuracy: 92.00%
#          - Test loss: 1.153054, Test accuracy: 75.20%
# -------------------------------------------------------------
# Epoch 22 - Train loss: 0.773773, Train accuracy: 92.00%
#          - Test loss: 1.125415, Test accuracy: 76.60%
# -------------------------------------------------------------
# Epoch 23 - Train loss: 0.753073, Train accuracy: 92.67%
#          - Test loss: 1.102036, Test accuracy: 76.20%
# -------------------------------------------------------------
# Epoch 24 - Train loss: 0.709146, Train accuracy: 92.67%
#          - Test loss: 1.076613, Test accuracy: 76.40%
# -------------------------------------------------------------
# Epoch 25 - Train loss: 0.702935, Train accuracy: 94.00%
#          - Test loss: 1.055649, Test accuracy: 76.60%
# -------------------------------------------------------------
# Epoch 26 - Train loss: 0.677126, Train accuracy: 94.00%
#          - Test loss: 1.040521, Test accuracy: 76.10%
# -------------------------------------------------------------
# Epoch 27 - Train loss: 0.649923, Train accuracy: 94.00%
#          - Test loss: 1.020097, Test accuracy: 76.70%
# -------------------------------------------------------------
# Epoch 28 - Train loss: 0.633476, Train accuracy: 94.00%
#          - Test loss: 1.002984, Test accuracy: 76.90%
# -------------------------------------------------------------
# Epoch 29 - Train loss: 0.605819, Train accuracy: 94.67%
#          - Test loss: 0.989193, Test accuracy: 76.70%
# -------------------------------------------------------------
# Epoch 30 - Train loss: 0.576259, Train accuracy: 95.33%
#          - Test loss: 0.970084, Test accuracy: 77.00%
# -------------------------------------------------------------
# Epoch 31 - Train loss: 0.557329, Train accuracy: 96.00%
#          - Test loss: 0.954551, Test accuracy: 76.80%
# -------------------------------------------------------------
# Epoch 32 - Train loss: 0.549309, Train accuracy: 96.67%
#          - Test loss: 0.939398, Test accuracy: 76.80%
# -------------------------------------------------------------
# Epoch 33 - Train loss: 0.521726, Train accuracy: 96.00%
#          - Test loss: 0.923350, Test accuracy: 77.40%
# -------------------------------------------------------------
# Epoch 34 - Train loss: 0.502438, Train accuracy: 96.67%
#          - Test loss: 0.913135, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 35 - Train loss: 0.494882, Train accuracy: 96.67%
#          - Test loss: 0.898790, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 36 - Train loss: 0.489758, Train accuracy: 96.67%
#          - Test loss: 0.889131, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 37 - Train loss: 0.462300, Train accuracy: 96.67%
#          - Test loss: 0.879149, Test accuracy: 77.30%
# -------------------------------------------------------------
# Epoch 38 - Train loss: 0.452009, Train accuracy: 96.67%
#          - Test loss: 0.868152, Test accuracy: 77.80%
# -------------------------------------------------------------
# Epoch 39 - Train loss: 0.437207, Train accuracy: 96.67%
#          - Test loss: 0.858171, Test accuracy: 78.10%
# -------------------------------------------------------------
# Epoch 40 - Train loss: 0.436415, Train accuracy: 96.67%
#          - Test loss: 0.851103, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 41 - Train loss: 0.416388, Train accuracy: 96.67%
#          - Test loss: 0.845791, Test accuracy: 77.70%
# -------------------------------------------------------------
# Epoch 42 - Train loss: 0.407430, Train accuracy: 96.67%
#          - Test loss: 0.836059, Test accuracy: 77.60%
# -------------------------------------------------------------
# Epoch 43 - Train loss: 0.396124, Train accuracy: 97.33%
#          - Test loss: 0.825398, Test accuracy: 78.20%
# -------------------------------------------------------------
# Epoch 44 - Train loss: 0.380302, Train accuracy: 97.33%
#          - Test loss: 0.818590, Test accuracy: 77.90%
# -------------------------------------------------------------
# Epoch 45 - Train loss: 0.368054, Train accuracy: 97.33%
#          - Test loss: 0.811170, Test accuracy: 78.10%
# -------------------------------------------------------------
# Epoch 46 - Train loss: 0.366069, Train accuracy: 97.33%
#          - Test loss: 0.805788, Test accuracy: 78.30%
# -------------------------------------------------------------
# Epoch 47 - Train loss: 0.359031, Train accuracy: 98.00%
#          - Test loss: 0.799204, Test accuracy: 78.10%
# -------------------------------------------------------------
# Epoch 48 - Train loss: 0.341664, Train accuracy: 98.00%
#          - Test loss: 0.794751, Test accuracy: 78.00%
# -------------------------------------------------------------
# Epoch 49 - Train loss: 0.336384, Train accuracy: 97.33%
#          - Test loss: 0.788968, Test accuracy: 78.20%
# -------------------------------------------------------------
# Epoch 50 - Train loss: 0.325118, Train accuracy: 98.00%
#          - Test loss: 0.782815, Test accuracy: 78.30%
# -------------------------------------------------------------
# Epoch 51 - Train loss: 0.320270, Train accuracy: 98.67%
#          - Test loss: 0.776536, Test accuracy: 78.50%
# -------------------------------------------------------------
# Epoch 52 - Train loss: 0.315573, Train accuracy: 98.67%
#          - Test loss: 0.770589, Test accuracy: 78.80%
# -------------------------------------------------------------
# Epoch 53 - Train loss: 0.308658, Train accuracy: 98.67%
#          - Test loss: 0.767476, Test accuracy: 78.40%
# -------------------------------------------------------------
# Epoch 54 - Train loss: 0.301196, Train accuracy: 99.33%
#          - Test loss: 0.761510, Test accuracy: 78.70%
# -------------------------------------------------------------
# Epoch 55 - Train loss: 0.285348, Train accuracy: 99.33%
#          - Test loss: 0.756053, Test accuracy: 78.60%
# -------------------------------------------------------------
# Epoch 56 - Train loss: 0.293662, Train accuracy: 99.33%
#          - Test loss: 0.753760, Test accuracy: 78.60%
# -------------------------------------------------------------
# Epoch 57 - Train loss: 0.280807, Train accuracy: 99.33%
#          - Test loss: 0.751788, Test accuracy: 78.30%
# -------------------------------------------------------------
# Epoch 58 - Train loss: 0.279123, Train accuracy: 99.33%
#          - Test loss: 0.748371, Test accuracy: 78.40%
# -------------------------------------------------------------
# Epoch 59 - Train loss: 0.272249, Train accuracy: 99.33%
#          - Test loss: 0.742684, Test accuracy: 78.60%
# -------------------------------------------------------------
# Epoch 60 - Train loss: 0.260907, Train accuracy: 99.33%
#          - Test loss: 0.739210, Test accuracy: 78.70%
# -------------------------------------------------------------
# Epoch 61 - Train loss: 0.251632, Train accuracy: 99.33%
#          - Test loss: 0.736244, Test accuracy: 78.90%
# -------------------------------------------------------------
# Epoch 62 - Train loss: 0.252314, Train accuracy: 99.33%
#          - Test loss: 0.732938, Test accuracy: 79.10%
# -------------------------------------------------------------
# Epoch 63 - Train loss: 0.247248, Train accuracy: 99.33%
#          - Test loss: 0.727223, Test accuracy: 79.00%
# -------------------------------------------------------------
# Epoch 64 - Train loss: 0.247221, Train accuracy: 99.33%
#          - Test loss: 0.724548, Test accuracy: 79.00%
# -------------------------------------------------------------
# Epoch 65 - Train loss: 0.237795, Train accuracy: 99.33%
#          - Test loss: 0.722870, Test accuracy: 78.80%
# -------------------------------------------------------------
# Epoch 66 - Train loss: 0.228404, Train accuracy: 99.33%
#          - Test loss: 0.721057, Test accuracy: 78.90%
# -------------------------------------------------------------
# Epoch 67 - Train loss: 0.229957, Train accuracy: 99.33%
#          - Test loss: 0.717074, Test accuracy: 78.90%
# -------------------------------------------------------------
# Epoch 68 - Train loss: 0.225128, Train accuracy: 99.33%
#          - Test loss: 0.715964, Test accuracy: 79.00%
# -------------------------------------------------------------
# Epoch 69 - Train loss: 0.219134, Train accuracy: 99.33%
#          - Test loss: 0.712443, Test accuracy: 79.20%
# -------------------------------------------------------------
# Epoch 70 - Train loss: 0.212277, Train accuracy: 99.33%
#          - Test loss: 0.708123, Test accuracy: 79.40%
# -------------------------------------------------------------
# Epoch 71 - Train loss: 0.211494, Train accuracy: 99.33%
#          - Test loss: 0.706724, Test accuracy: 79.20%
# -------------------------------------------------------------
# Epoch 72 - Train loss: 0.203368, Train accuracy: 99.33%
#          - Test loss: 0.703474, Test accuracy: 79.30%
# -------------------------------------------------------------
# Epoch 73 - Train loss: 0.202705, Train accuracy: 99.33%
#          - Test loss: 0.701538, Test accuracy: 79.10%
# -------------------------------------------------------------
# Epoch 74 - Train loss: 0.198854, Train accuracy: 99.33%
#          - Test loss: 0.700635, Test accuracy: 79.10%
# -------------------------------------------------------------
# Epoch 75 - Train loss: 0.201268, Train accuracy: 99.33%
#          - Test loss: 0.696968, Test accuracy: 79.30%
# -------------------------------------------------------------
# Epoch 76 - Train loss: 0.191852, Train accuracy: 99.33%
#          - Test loss: 0.695698, Test accuracy: 79.20%
# -------------------------------------------------------------
# Epoch 77 - Train loss: 0.191032, Train accuracy: 99.33%
#          - Test loss: 0.694148, Test accuracy: 79.20%
# -------------------------------------------------------------
# Epoch 78 - Train loss: 0.185640, Train accuracy: 99.33%
#          - Test loss: 0.692087, Test accuracy: 79.00%
# -------------------------------------------------------------
# Epoch 79 - Train loss: 0.182995, Train accuracy: 99.33%
#          - Test loss: 0.690380, Test accuracy: 79.10%
# -------------------------------------------------------------
# Epoch 80 - Train loss: 0.179512, Train accuracy: 99.33%
#          - Test loss: 0.689252, Test accuracy: 79.40%
# -------------------------------------------------------------
# Epoch 81 - Train loss: 0.176490, Train accuracy: 99.33%
#          - Test loss: 0.686371, Test accuracy: 79.30%
# -------------------------------------------------------------
# Epoch 82 - Train loss: 0.171846, Train accuracy: 99.33%
#          - Test loss: 0.685334, Test accuracy: 79.20%
# -------------------------------------------------------------
# Epoch 83 - Train loss: 0.167393, Train accuracy: 99.33%
#          - Test loss: 0.683396, Test accuracy: 79.20%
# -------------------------------------------------------------
# Epoch 84 - Train loss: 0.166029, Train accuracy: 99.33%
#          - Test loss: 0.682382, Test accuracy: 79.30%
# -------------------------------------------------------------
# Epoch 85 - Train loss: 0.162234, Train accuracy: 99.33%
#          - Test loss: 0.680158, Test accuracy: 79.30%
# -------------------------------------------------------------
# Epoch 86 - Train loss: 0.160099, Train accuracy: 99.33%
#          - Test loss: 0.679937, Test accuracy: 79.30%
# -------------------------------------------------------------
# Epoch 87 - Train loss: 0.160412, Train accuracy: 99.33%
#          - Test loss: 0.678752, Test accuracy: 79.40%
# -------------------------------------------------------------
# Epoch 88 - Train loss: 0.156918, Train accuracy: 99.33%
#          - Test loss: 0.676754, Test accuracy: 79.20%
# -------------------------------------------------------------
# Epoch 89 - Train loss: 0.151262, Train accuracy: 99.33%
#          - Test loss: 0.675115, Test accuracy: 79.40%
# -------------------------------------------------------------
# Epoch 90 - Train loss: 0.153012, Train accuracy: 99.33%
#          - Test loss: 0.675262, Test accuracy: 79.20%
# -------------------------------------------------------------
# Epoch 91 - Train loss: 0.151259, Train accuracy: 99.33%
#          - Test loss: 0.673463, Test accuracy: 79.40%
# -------------------------------------------------------------
# Epoch 92 - Train loss: 0.145036, Train accuracy: 99.33%
#          - Test loss: 0.671713, Test accuracy: 79.30%
# -------------------------------------------------------------
# Epoch 93 - Train loss: 0.145154, Train accuracy: 99.33%
#          - Test loss: 0.669957, Test accuracy: 79.30%
# -------------------------------------------------------------
# Epoch 94 - Train loss: 0.141519, Train accuracy: 100.00%
#          - Test loss: 0.667966, Test accuracy: 79.20%
# -------------------------------------------------------------
# Epoch 95 - Train loss: 0.139984, Train accuracy: 100.00%
#          - Test loss: 0.667193, Test accuracy: 79.10%
# -------------------------------------------------------------
# Epoch 96 - Train loss: 0.135847, Train accuracy: 100.00%
#          - Test loss: 0.667010, Test accuracy: 79.10%
# -------------------------------------------------------------
# Epoch 97 - Train loss: 0.134666, Train accuracy: 100.00%
#          - Test loss: 0.666272, Test accuracy: 79.10%
# -------------------------------------------------------------
# Epoch 98 - Train loss: 0.136599, Train accuracy: 100.00%
#          - Test loss: 0.666636, Test accuracy: 79.00%
# -------------------------------------------------------------
# Epoch 99 - Train loss: 0.128816, Train accuracy: 100.00%
#          - Test loss: 0.666715, Test accuracy: 79.00%
# -------------------------------------------------------------
# Epoch 100 - Train loss: 0.130373, Train accuracy: 100.00%
#          - Test loss: 0.666192, Test accuracy: 78.90%
# -------------------------------------------------------------

# %%
# Plot the loss values and accuracies for train/test
plot_eval_results(train_loss_epochs, test_loss_epochs, train_accuracy_epochs, test_accuracy_epochs)

# %% [markdown]
# # Task 4: Data Augmentation (20 points)
#
# In this task, we will explore the concept of data augmentation, which is a powerful technique used to enhance the diversity of our training dataset without collecting new data. By applying various transformations to the original training images, we can create modified versions of these images.
# We can then use these modified images to train our model with a "richer" set of examples.The use of data augmentation helps to improve the robustness and generalization of our models. Data augmentation is particularly beneficial in tasks like image classification, where we expect the model to be invariant to slight variations of images (e.g., rotation, cropping, blurring, etc.)
#
# For this task, you are given a code that uses Gaussian Blur augmentation, which applies a Gaussian filter to slightly blur the images. If you run the code, you will see that this type of augmentation actually makes the model less accurate (compared with Task 3, SVM test accuracy)
#
# For this task, you must explore other types of data augmentation and find one that improves the test accuracy by at least 1 percent compared with not using any augmentation (i.e., compared with Task 3, SVM test accuracy). Only change the augmentation approach, and keep the other parts of the code unchanged. Read the PyTorch documentation on different augmentation techniques [here](https://pytorch.org/vision/stable/transforms.html), and then try to identify a good augmentation method from them. Report the augmentation approach that you used, and explain why you think it helps. Also include train/test accuracy plots per epoch, and the train/test accuracy at the final epoch.
#
#
# Even if you find that your method does not improve upon the previous task, submit whatever you have completed to get partial marks.

# %%
# TRANSFOMATION
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.1),
    transforms.ToTensor()
])
train_loader_2, test_loader_2 = get_data_loaders(train_data_percentage, test_data_percentage, batch_size, transform)

# %%
# Run the ModifiedModel with Hinge Loss (SVM)
# Model initialization

model = ModifiedModel(input_size, num_classes)
criterion = nn.MultiMarginLoss()
optimizer = optim.SGD(model.parameters(), lr = learning_rate)


train_loss_epochs = []
test_loss_epochs = []
train_accuracy_epochs = []
test_accuracy_epochs = []

for epoch in range(num_epochs):
  for image, true_label_batch in train_loader_2:
    optimizer.zero_grad()
    outputs = model(image)
    loss = criterion(outputs, true_label_batch)

    loss.backward()
    optimizer.step()

  train_acc, train_loss = eval(model, train_loader_2, criterion)
  test_acc, test_loss = eval(model, test_loader_2, criterion)

  train_loss_epochs.append(train_loss)
  test_loss_epochs.append(test_loss)

  train_accuracy_epochs.append(train_acc)
  test_accuracy_epochs.append(test_acc)

  print(f'Epoch {epoch+1:02d} - Train loss: {train_loss:.6f}, Train accuracy: {train_acc:.2f}%')
  print(f'         - Test loss: {test_loss:.6f}, Test accuracy: {test_acc:.2f}%')
  print("-------------------------------------------------------------")
# Out:
# Epoch 01 - Train loss: 0.760858, Train accuracy: 22.00%
#          - Test loss: 0.817682, Test accuracy: 18.50%
# -------------------------------------------------------------
# Epoch 02 - Train loss: 0.651455, Train accuracy: 43.33%
#          - Test loss: 0.737582, Test accuracy: 33.20%
# -------------------------------------------------------------
# Epoch 03 - Train loss: 0.572812, Train accuracy: 43.33%
#          - Test loss: 0.673208, Test accuracy: 34.80%
# -------------------------------------------------------------
# Epoch 04 - Train loss: 0.491509, Train accuracy: 53.33%
#          - Test loss: 0.600800, Test accuracy: 40.70%
# -------------------------------------------------------------
# Epoch 05 - Train loss: 0.430135, Train accuracy: 58.67%
#          - Test loss: 0.542919, Test accuracy: 44.70%
# -------------------------------------------------------------
# Epoch 06 - Train loss: 0.376496, Train accuracy: 61.33%
#          - Test loss: 0.483481, Test accuracy: 50.20%
# -------------------------------------------------------------
# Epoch 07 - Train loss: 0.309436, Train accuracy: 78.00%
#          - Test loss: 0.423644, Test accuracy: 61.60%
# -------------------------------------------------------------
# Epoch 08 - Train loss: 0.292232, Train accuracy: 82.00%
#          - Test loss: 0.377016, Test accuracy: 72.00%
# -------------------------------------------------------------
# Epoch 09 - Train loss: 0.223101, Train accuracy: 88.00%
#          - Test loss: 0.336139, Test accuracy: 73.00%
# -------------------------------------------------------------
# Epoch 10 - Train loss: 0.216683, Train accuracy: 89.33%
#          - Test loss: 0.312037, Test accuracy: 76.40%
# -------------------------------------------------------------
# Epoch 11 - Train loss: 0.180271, Train accuracy: 91.33%
#          - Test loss: 0.289900, Test accuracy: 75.90%
# -------------------------------------------------------------
# Epoch 12 - Train loss: 0.167332, Train accuracy: 90.00%
#          - Test loss: 0.276601, Test accuracy: 75.80%
# -------------------------------------------------------------
# Epoch 13 - Train loss: 0.168230, Train accuracy: 90.00%
#          - Test loss: 0.262070, Test accuracy: 77.20%
# -------------------------------------------------------------
# Epoch 14 - Train loss: 0.146334, Train accuracy: 91.33%
#          - Test loss: 0.252608, Test accuracy: 77.20%
# -------------------------------------------------------------
# Epoch 15 - Train loss: 0.136118, Train accuracy: 92.67%
#          - Test loss: 0.246321, Test accuracy: 76.30%
# -------------------------------------------------------------
# Epoch 16 - Train loss: 0.123465, Train accuracy: 94.00%
#          - Test loss: 0.232283, Test accuracy: 79.50%
# -------------------------------------------------------------
# Epoch 17 - Train loss: 0.107957, Train accuracy: 95.33%
#          - Test loss: 0.225375, Test accuracy: 79.70%
# -------------------------------------------------------------
# Epoch 18 - Train loss: 0.105598, Train accuracy: 95.33%
#          - Test loss: 0.220680, Test accuracy: 79.30%
# -------------------------------------------------------------
# Epoch 19 - Train loss: 0.113522, Train accuracy: 94.00%
#          - Test loss: 0.213853, Test accuracy: 79.90%
# -------------------------------------------------------------
# Epoch 20 - Train loss: 0.112742, Train accuracy: 94.00%
#          - Test loss: 0.207158, Test accuracy: 80.10%
# -------------------------------------------------------------
# Epoch 21 - Train loss: 0.107074, Train accuracy: 92.67%
#          - Test loss: 0.201406, Test accuracy: 80.30%
# -------------------------------------------------------------
# Epoch 22 - Train loss: 0.102291, Train accuracy: 94.67%
#          - Test loss: 0.198225, Test accuracy: 79.40%
# -------------------------------------------------------------
# Epoch 23 - Train loss: 0.083043, Train accuracy: 97.33%
#          - Test loss: 0.193143, Test accuracy: 80.90%
# -------------------------------------------------------------
# Epoch 24 - Train loss: 0.079116, Train accuracy: 96.00%
#          - Test loss: 0.190877, Test accuracy: 80.60%
# -------------------------------------------------------------
# Epoch 25 - Train loss: 0.078045, Train accuracy: 96.67%
#          - Test loss: 0.187183, Test accuracy: 81.00%
# -------------------------------------------------------------
# Epoch 26 - Train loss: 0.083945, Train accuracy: 94.00%
#          - Test loss: 0.186610, Test accuracy: 81.20%
# -------------------------------------------------------------
# Epoch 27 - Train loss: 0.076730, Train accuracy: 97.33%
#          - Test loss: 0.181649, Test accuracy: 81.80%
# -------------------------------------------------------------
# Epoch 28 - Train loss: 0.067240, Train accuracy: 96.67%
#          - Test loss: 0.180258, Test accuracy: 81.40%
# -------------------------------------------------------------
# Epoch 29 - Train loss: 0.078728, Train accuracy: 96.67%
#          - Test loss: 0.177287, Test accuracy: 82.00%
# -------------------------------------------------------------
# Epoch 30 - Train loss: 0.061023, Train accuracy: 97.33%
#          - Test loss: 0.175244, Test accuracy: 82.80%
# -------------------------------------------------------------
# Epoch 31 - Train loss: 0.058566, Train accuracy: 98.00%
#          - Test loss: 0.172831, Test accuracy: 82.30%
# -------------------------------------------------------------
# Epoch 32 - Train loss: 0.055749, Train accuracy: 98.00%
#          - Test loss: 0.170894, Test accuracy: 82.20%
# -------------------------------------------------------------
# Epoch 33 - Train loss: 0.059506, Train accuracy: 98.00%
#          - Test loss: 0.168911, Test accuracy: 82.50%
# -------------------------------------------------------------
# Epoch 34 - Train loss: 0.059077, Train accuracy: 97.33%
#          - Test loss: 0.168010, Test accuracy: 82.30%
# -------------------------------------------------------------
# Epoch 35 - Train loss: 0.069074, Train accuracy: 93.33%
#          - Test loss: 0.165323, Test accuracy: 82.00%
# -------------------------------------------------------------
# Epoch 36 - Train loss: 0.057619, Train accuracy: 96.67%
#          - Test loss: 0.163856, Test accuracy: 82.60%
# -------------------------------------------------------------
# Epoch 37 - Train loss: 0.046655, Train accuracy: 98.67%
#          - Test loss: 0.163487, Test accuracy: 82.10%
# -------------------------------------------------------------
# Epoch 38 - Train loss: 0.059149, Train accuracy: 96.67%
#          - Test loss: 0.162765, Test accuracy: 82.40%
# -------------------------------------------------------------
# Epoch 39 - Train loss: 0.051646, Train accuracy: 97.33%
#          - Test loss: 0.161709, Test accuracy: 83.00%
# -------------------------------------------------------------
# Epoch 40 - Train loss: 0.048505, Train accuracy: 97.33%
#          - Test loss: 0.160575, Test accuracy: 82.70%
# -------------------------------------------------------------
# Epoch 41 - Train loss: 0.049560, Train accuracy: 98.00%
#          - Test loss: 0.159920, Test accuracy: 82.40%
# -------------------------------------------------------------
# Epoch 42 - Train loss: 0.045630, Train accuracy: 98.00%
#          - Test loss: 0.159210, Test accuracy: 83.10%
# -------------------------------------------------------------
# Epoch 43 - Train loss: 0.045367, Train accuracy: 97.33%
#          - Test loss: 0.158424, Test accuracy: 82.60%
# -------------------------------------------------------------
# Epoch 44 - Train loss: 0.038949, Train accuracy: 97.33%
#          - Test loss: 0.156737, Test accuracy: 83.20%
# -------------------------------------------------------------
# Epoch 45 - Train loss: 0.043155, Train accuracy: 95.33%
#          - Test loss: 0.155560, Test accuracy: 83.90%
# -------------------------------------------------------------
# Epoch 46 - Train loss: 0.050427, Train accuracy: 96.67%
#          - Test loss: 0.154658, Test accuracy: 83.20%
# -------------------------------------------------------------
# Epoch 47 - Train loss: 0.043934, Train accuracy: 97.33%
#          - Test loss: 0.154987, Test accuracy: 82.80%
# -------------------------------------------------------------
# Epoch 48 - Train loss: 0.038937, Train accuracy: 98.00%
#          - Test loss: 0.153652, Test accuracy: 82.50%
# -------------------------------------------------------------
# Epoch 49 - Train loss: 0.052135, Train accuracy: 94.67%
#          - Test loss: 0.154671, Test accuracy: 82.50%
# -------------------------------------------------------------
# Epoch 50 - Train loss: 0.045683, Train accuracy: 96.00%
#          - Test loss: 0.153271, Test accuracy: 83.00%
# -------------------------------------------------------------
# Epoch 51 - Train loss: 0.036058, Train accuracy: 96.67%
#          - Test loss: 0.151161, Test accuracy: 83.70%
# -------------------------------------------------------------
# Epoch 52 - Train loss: 0.042778, Train accuracy: 95.33%
#          - Test loss: 0.151722, Test accuracy: 82.80%
# -------------------------------------------------------------
# Epoch 53 - Train loss: 0.037201, Train accuracy: 96.00%
#          - Test loss: 0.150200, Test accuracy: 82.90%
# -------------------------------------------------------------
# Epoch 54 - Train loss: 0.037462, Train accuracy: 96.67%
#          - Test loss: 0.148995, Test accuracy: 83.10%
# -------------------------------------------------------------
# Epoch 55 - Train loss: 0.046811, Train accuracy: 96.00%
#          - Test loss: 0.149642, Test accuracy: 83.40%
# -------------------------------------------------------------
# Epoch 56 - Train loss: 0.035631, Train accuracy: 98.00%
#          - Test loss: 0.148339, Test accuracy: 83.00%
# -------------------------------------------------------------
# Epoch 57 - Train loss: 0.048836, Train accuracy: 95.33%
#          - Test loss: 0.148896, Test accuracy: 83.50%
# -------------------------------------------------------------
# Epoch 58 - Train loss: 0.037371, Train accuracy: 96.00%
#          - Test loss: 0.147023, Test accuracy: 83.50%
# -------------------------------------------------------------
# Epoch 59 - Train loss: 0.033156, Train accuracy: 95.33%
#          - Test loss: 0.146171, Test accuracy: 83.20%
# -------------------------------------------------------------
# Epoch 60 - Train loss: 0.024396, Train accuracy: 98.67%
#          - Test loss: 0.146032, Test accuracy: 83.10%
# -------------------------------------------------------------
# Epoch 61 - Train loss: 0.040898, Train accuracy: 96.00%
#          - Test loss: 0.146666, Test accuracy: 83.10%
# -------------------------------------------------------------
# Epoch 62 - Train loss: 0.024480, Train accuracy: 99.33%
#          - Test loss: 0.145428, Test accuracy: 83.20%
# -------------------------------------------------------------
# Epoch 63 - Train loss: 0.026643, Train accuracy: 97.33%
#          - Test loss: 0.144607, Test accuracy: 83.00%
# -------------------------------------------------------------
# Epoch 64 - Train loss: 0.042716, Train accuracy: 96.67%
#          - Test loss: 0.144759, Test accuracy: 83.30%
# -------------------------------------------------------------
# Epoch 65 - Train loss: 0.044106, Train accuracy: 96.00%
#          - Test loss: 0.145551, Test accuracy: 83.20%
# -------------------------------------------------------------
# Epoch 66 - Train loss: 0.035411, Train accuracy: 97.33%
#          - Test loss: 0.144234, Test accuracy: 83.50%
# -------------------------------------------------------------
# Epoch 67 - Train loss: 0.031600, Train accuracy: 96.00%
#          - Test loss: 0.144547, Test accuracy: 83.30%
# -------------------------------------------------------------
# Epoch 68 - Train loss: 0.019178, Train accuracy: 99.33%
#          - Test loss: 0.143147, Test accuracy: 83.40%
# -------------------------------------------------------------
# Epoch 69 - Train loss: 0.029248, Train accuracy: 98.00%
#          - Test loss: 0.143804, Test accuracy: 82.90%
# -------------------------------------------------------------
# Epoch 70 - Train loss: 0.019907, Train accuracy: 99.33%
#          - Test loss: 0.143208, Test accuracy: 83.20%
# -------------------------------------------------------------
# Epoch 71 - Train loss: 0.029681, Train accuracy: 98.00%
#          - Test loss: 0.142378, Test accuracy: 83.10%
# -------------------------------------------------------------
# Epoch 72 - Train loss: 0.030282, Train accuracy: 97.33%
#          - Test loss: 0.142528, Test accuracy: 83.40%
# -------------------------------------------------------------
# Epoch 73 - Train loss: 0.031553, Train accuracy: 97.33%
#          - Test loss: 0.142028, Test accuracy: 83.20%
# -------------------------------------------------------------
# Epoch 74 - Train loss: 0.023246, Train accuracy: 98.00%
#          - Test loss: 0.142955, Test accuracy: 83.20%
# -------------------------------------------------------------
# Epoch 75 - Train loss: 0.024718, Train accuracy: 99.33%
#          - Test loss: 0.141617, Test accuracy: 83.40%
# -------------------------------------------------------------
# Epoch 76 - Train loss: 0.021380, Train accuracy: 99.33%
#          - Test loss: 0.141033, Test accuracy: 83.50%
# -------------------------------------------------------------
# Epoch 77 - Train loss: 0.026368, Train accuracy: 98.00%
#          - Test loss: 0.140778, Test accuracy: 83.30%
# -------------------------------------------------------------
# Epoch 78 - Train loss: 0.027103, Train accuracy: 96.67%
#          - Test loss: 0.140686, Test accuracy: 83.60%
# -------------------------------------------------------------
# Epoch 79 - Train loss: 0.018950, Train accuracy: 98.00%
#          - Test loss: 0.140538, Test accuracy: 83.30%
# -------------------------------------------------------------
# Epoch 80 - Train loss: 0.019389, Train accuracy: 99.33%
#          - Test loss: 0.139612, Test accuracy: 83.20%
# -------------------------------------------------------------
# Epoch 81 - Train loss: 0.023236, Train accuracy: 98.67%
#          - Test loss: 0.139513, Test accuracy: 83.30%
# -------------------------------------------------------------
# Epoch 82 - Train loss: 0.015966, Train accuracy: 98.00%
#          - Test loss: 0.138706, Test accuracy: 83.30%
# -------------------------------------------------------------
# Epoch 83 - Train loss: 0.018787, Train accuracy: 98.67%
#          - Test loss: 0.138816, Test accuracy: 83.30%
# -------------------------------------------------------------
# Epoch 84 - Train loss: 0.012428, Train accuracy: 100.00%
#          - Test loss: 0.138548, Test accuracy: 83.30%
# -------------------------------------------------------------
# Epoch 85 - Train loss: 0.016435, Train accuracy: 98.67%
#          - Test loss: 0.138374, Test accuracy: 83.20%
# -------------------------------------------------------------
# Epoch 86 - Train loss: 0.019318, Train accuracy: 98.00%
#          - Test loss: 0.139153, Test accuracy: 83.00%
# -------------------------------------------------------------
# Epoch 87 - Train loss: 0.018772, Train accuracy: 98.67%
#          - Test loss: 0.138558, Test accuracy: 83.10%
# -------------------------------------------------------------
# Epoch 88 - Train loss: 0.025850, Train accuracy: 97.33%
#          - Test loss: 0.138608, Test accuracy: 83.20%
# -------------------------------------------------------------
# Epoch 89 - Train loss: 0.019607, Train accuracy: 98.67%
#          - Test loss: 0.138226, Test accuracy: 83.40%
# -------------------------------------------------------------
# Epoch 90 - Train loss: 0.016277, Train accuracy: 100.00%
#          - Test loss: 0.137673, Test accuracy: 83.50%
# -------------------------------------------------------------
# Epoch 91 - Train loss: 0.028311, Train accuracy: 98.67%
#          - Test loss: 0.137441, Test accuracy: 83.30%
# -------------------------------------------------------------
# Epoch 92 - Train loss: 0.024305, Train accuracy: 98.00%
#          - Test loss: 0.137948, Test accuracy: 83.10%
# -------------------------------------------------------------
# Epoch 93 - Train loss: 0.017962, Train accuracy: 99.33%
#          - Test loss: 0.137104, Test accuracy: 83.60%
# -------------------------------------------------------------
# Epoch 94 - Train loss: 0.012202, Train accuracy: 99.33%
#          - Test loss: 0.136686, Test accuracy: 83.20%
# -------------------------------------------------------------
# Epoch 95 - Train loss: 0.021375, Train accuracy: 97.33%
#          - Test loss: 0.136600, Test accuracy: 83.50%
# -------------------------------------------------------------
# Epoch 96 - Train loss: 0.031804, Train accuracy: 99.33%
#          - Test loss: 0.136649, Test accuracy: 83.50%
# -------------------------------------------------------------
# Epoch 97 - Train loss: 0.015009, Train accuracy: 98.67%
#          - Test loss: 0.136797, Test accuracy: 82.90%
# -------------------------------------------------------------
# Epoch 98 - Train loss: 0.014179, Train accuracy: 100.00%
#          - Test loss: 0.136447, Test accuracy: 82.90%
# -------------------------------------------------------------
# Epoch 99 - Train loss: 0.012933, Train accuracy: 98.67%
#          - Test loss: 0.136341, Test accuracy: 82.90%
# -------------------------------------------------------------
# Epoch 100 - Train loss: 0.016681, Train accuracy: 99.33%
#          - Test loss: 0.136543, Test accuracy: 83.10%
# -------------------------------------------------------------

# %%
# Plot the loss values and accuracies for train/test
plot_eval_results(train_loss_epochs, test_loss_epochs, train_accuracy_epochs, test_accuracy_epochs)
